# %% [markdown]
# <a href="https://colab.research.google.com/github/YanjunLin-Andrie/NLP_SpaCy_eBay/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import all libraries and dependencies

import pandas as pd
import spacy
import json
import random
import numpy as np
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
from spacy.tokens import Span
from collections import Counter
from string import punctuation
from random import shuffle
from spacy.scorer import Scorer
from spacy.tokens import Doc
from spacy.training.example import Example

# %%
# Import training dataset
from google.colab import files
# uploaded = files.upload()
#read the file
ttt = pd.read_csv('Train_Tagged_Titles.tsv', on_bad_lines = 'skip', sep = '\t')
ttt = ttt.replace(np.nan, 'Brand', regex=True)
#read the file
lt_sm = pd.read_csv('Listing_Titles_sm.tsv')

# %%
# File i/o
def load_data(file):
  with open(file, 'r', encoding = 'utf-8') as f:
    data = json.load(f)
  return (data)

def save_data(file, data):
  with open(file, 'w', encoding = 'utf-8') as f:
    json.dump(data, f, indent = 4)

# %% [markdown]
# ## Use entity ruler to create custom NER model and save to file

# %%
# Get all of the unique tags from ttt dataframe and change them to a list format
all_tags = ttt["Tag"].unique().tolist()

# Create an empty list to collect all the patterns of the entity
patterns = []
# Get all of the tag names
for tag in all_tags:
  # Save list of Tokens under the tag name
  items = ttt["Token"].loc[ttt["Tag"] == f"{tag}"].tolist()
  # Loops through created list of Tokens
  for item in items:
    # Adds the new pattern to pattens list
    patterns.append({'label': f'{tag}', 'pattern': item})

# %%
# Create model
def generate_rules(patterns):

  # Create a blank English model
  nlp = spacy.blank('en')
  # Create the entity ruler and add to entity pipeline
  ruler = nlp.add_pipe('entity_ruler')
  # add patterns list to model
  ruler.add_patterns(patterns)

  # Save model with patterns
  nlp.to_disk('./ebay_ner')

# call function
generate_rules(patterns)

# %% [markdown]
# ## Test on the created NER model

# %%
# Load model
nlp = spacy.load('./ebay_ner')

# %%
# Collecting testing dataset and convert testing data to list format
sentance_list = lt_sm['Title'].tolist()
test = sentance_list[35:45]
test
# Out:
# ['Marc Jacobs Black Leather Crossbody Bag ( M0013555-001 ) $ 275.00 NWT',
#  'Mimco Echo tote bag - Used but in New condition',
#  'Laurel Burch purse hand bag cut out cats geometric 15x9x4 brown',
#  "VERSACE JEANS women 's CLUTCH E1VVBBUX_71494",
#  'Brighton Handbag Shoulder Bag Tote Raised Flowers Vines Enamel Butterfly',
#  '2021 Solid Jacquemus Crocodile Pattern Mini Crossbody Handbag Shoulder Bag',
#  'Fossil Small Green Leather Crossbody Shoulder Bag Brass Adjustable w / key Mint',
#  'COACH F10909 Soho Black Leather Hobo Shoulder satchel FLAWLESS !',
#  '( Velours-Grün ) - Bags4Less Messenger Bag , Velours-Grün ( Green ) - F3151_230 . Fr',
#  'Tesco Cute Peter Rabbit Beatrix Potter Shopping Tote Bag New']

# %%
# Pass test data into built nlp model to extract entities and tags
for i in test:
    doc = nlp(i)
    results = []
    for ent in doc.ents:
      results.append([ent.text,ent.label_])
    print(results)
# Out:
# [['Marc', 'Product Line'], ['Jacobs', 'Brand'], ['Black', 'Brand'], ['Leather', 'Material'], ['Crossbody', 'Type'], ['Bag', 'Type'], ['(', 'No Tag'], ['-', 'No Tag'], ['001', 'No Tag'], [')', 'No Tag'], ['$', 'No Tag'], ['NWT', 'No Tag']]
# [['tote', 'Brand'], ['bag', 'Brand'], ['-', 'No Tag'], ['Used', 'Obscure'], ['in', 'Obscure'], ['New', 'No Tag'], ['condition', 'No Tag']]
# [['Laurel', 'Pattern'], ['Burch', 'Brand'], ['purse', 'Type'], ['hand', 'Brand'], ['bag', 'Obscure'], ['out', 'No Tag'], ['brown', 'Color']]
# [['VERSACE', 'Brand'], ['JEANS', 'Brand'], ['women', 'Department'], ["'s", 'Brand'], ['CLUTCH', 'Brand']]
# [['Brighton', 'Brand'], ['Handbag', 'Type'], ['Shoulder', 'Handle Style'], ['Bag', 'Brand'], ['Tote', 'Brand'], ['Raised', 'No Tag'], ['Flowers', 'Brand'], ['Vines', 'Pattern'], ['Enamel', 'Brand'], ['Butterfly', 'Pattern']]
# [['2021', 'No Tag'], ['Solid', 'No Tag'], ['Crocodile', 'Pattern'], ['Pattern', 'No Tag'], ['Mini', 'Model'], ['Crossbody', 'Brand'], ['Handbag', 'Type'], ['Shoulder', 'Handle Style'], ['Bag', 'Type']]
# [['Fossil', 'Brand'], ['Small', 'Brand'], ['Green', 'Brand'], ['Leather', 'Material'], ['Crossbody', 'Type'], ['Shoulder', 'Handle Style'], ['Bag', 'Brand'], ['Brass', 'Brand'], ['Adjustable', 'Features'], ['w', 'No Tag'], ['/', 'Handle/Strap Material'], ['Mint', 'No Tag']]
# [['COACH', 'Brand'], ['Soho', 'Product Line'], ['Black', 'Brand'], ['Leather', 'Obscure'], ['Hobo', 'Type'], ['Shoulder', 'Handle Style'], ['satchel', 'Type'], ['!', 'No Tag']]
# [['(', 'No Tag'], ['-', 'Brand'], [')', 'No Tag'], ['-', 'Obscure'], ['Messenger', 'Type'], ['Bag', 'Type'], [',', 'Obscure'], ['-', 'No Tag'], ['(', 'No Tag'], ['Green', 'Brand'], [')', 'No Tag'], ['-', 'No Tag'], ['.', 'Obscure']]
# [['Cute', 'No Tag'], ['Rabbit', 'Pattern'], ['Potter', 'Brand'], ['Shopping', 'Brand'], ['Tote', 'Type'], ['Bag', 'Type'], ['New', 'Country/Region of Manufacture']]

# %%
# Optional: save tested data
# save_data('./test.json', results)

# %% [markdown]
# ## Create NER training set

# %%
# Load model
nlp = spacy.load('./ebay_ner') 

TRAIN_DATA = []
for item in ttt['Title'].unique().tolist():
  doc = nlp(item)
  entities = []
  for ent in doc.ents:
    entities.append((ent.start_char, ent.end_char, ent.label_)) 
  if len(entities) > 0:
    TRAIN_DATA.append([item, {'entities': entities}]  )
# print(TRAIN_DATA)
# Save training data
save_data('./ebay_training_data.json', TRAIN_DATA)

# Right format, but json file only has one set of data

# %%
TRAIN_DATA[0]
# Out:
# ['LOUIS VUITTON M40096 Handbag Priscilla Multi-color canvas Multi-color canvas',
#  {'entities': [(0, 5, 'Product Line'),
#    (6, 13, 'Brand'),
#    (14, 20, 'MPN'),
#    (21, 28, 'Type'),
#    (29, 38, 'Model'),
#    (39, 50, 'Color'),
#    (51, 57, 'Brand'),
#    (58, 69, 'Color'),
#    (70, 76, 'Brand')]}]

# %%
len(TRAIN_DATA)
# Out:
# 3471

# %%
# TRAIN_DATA = []
# def train_data(model, text):
#   for item in text:
#     doc = nlp(item)
#     entities = []
#     for ent in doc.ents:
#       entities.append((ent.text, ent.label_))
#     if len(entities) > 0:
#       TRAIN_DATA = [item, {'entities': entities}]
#       print(TRAIN_DATA)
#   return (TRAIN_DATA)  
    


# # Load model
# nlp = spacy.load('./ebay_ner')  

# # Call function
# train_data(nlp, ttt['Title'].unique().tolist())

# # Save training data
# save_data('./ebay_training_data.json', TRAIN_DATA)

# print(len(TRAIN_DATA))

# %%
# TRAIN_DATA = []
# def train_data(model, text):
#   for item in text:
#     doc = nlp(item)
#     for ent in doc.ents:
#       entities = [[ent.text, ent.label_]]
#       for entity in entities:
#         TRAIN_DATA.append(entity)   

# # Load model
# nlp = spacy.load('./ebay_ner')  
# # Call function
# train_data(nlp, ttt['Title'].unique().tolist())
# # Save training data
# save_data('./ebay_training_data.json', TRAIN_DATA)


# print(len(TRAIN_DATA))
# Out:
# 38327

# %% [markdown]
# ## Train an NER model

# %%
# Load training dataset
TRAIN_DATA = load_data('./ebay_training_data.json')
TRAIN_DATA
# Out:
# [['LOUIS VUITTON M40096 Handbag Priscilla Multi-color canvas Multi-color canvas',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 20, 'MPN'],
#     [21, 28, 'Type'],
#     [29, 38, 'Model'],
#     [39, 50, 'Color'],
#     [51, 57, 'Brand'],
#     [58, 69, 'Color'],
#     [70, 76, 'Brand']]}],
#  ['LOUIS VUITTON Petit Noe Drawstring Shoulder Bag Monogram Leather M42226 39SD442',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 19, 'Brand'],
#     [20, 23, 'Brand'],
#     [24, 34, 'Closure'],
#     [35, 43, 'Handle Style'],
#     [44, 47, 'Brand'],
#     [48, 56, 'Brand'],
#     [57, 64, 'Trim Material'],
#     [65, 71, 'MPN'],
#     [72, 79, 'No Tag']]}],
#  ['LOUIS VUITTON Damier Azur Pochette Bosphore Shoulder Bag N51112 LV Auth yt523',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 20, 'Brand'],
#     [21, 25, 'Color'],
#     [26, 34, 'Model'],
#     [35, 43, 'Model'],
#     [44, 52, 'Brand'],
#     [53, 56, 'Type'],
#     [57, 63, 'MPN'],
#     [64, 66, 'MPN'],
#     [67, 71, 'No Tag'],
#     [72, 77, 'No Tag']]}],
#  ['GUCCI Bamboo 2Way Shoulder Bag Leather Brown Auth fm1002',
#   {'entities': [[0, 5, 'Pattern'],
#     [6, 12, 'Handle/Strap Material'],
#     [13, 17, 'Features'],
#     [18, 26, 'Handle Style'],
#     [27, 30, 'Type'],
#     [31, 38, 'Obscure'],
#     [39, 44, 'Color'],
#     [45, 49, 'No Tag'],
#     [50, 56, 'MPN']]}],
#  ['Rank AB Vintage Gucci Sherry line PVC Leather Clutch bag Brown From Japan A128',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 7, 'No Tag'],
#     [8, 15, 'No Tag'],
#     [16, 21, 'Brand'],
#     [22, 28, 'Product Line'],
#     [29, 33, 'Brand'],
#     [34, 37, 'Material'],
#     [38, 45, 'Handle/Strap Material'],
#     [46, 52, 'Type'],
#     [53, 56, 'Type'],
#     [57, 62, 'Color'],
#     [63, 67, 'No Tag'],
#     [68, 73, 'No Tag'],
#     [74, 78, 'No Tag']]}],
#  ['1970s NYC Bonnie Cashin Coach Brown Gray Leather Saddle Pouch Crossbody Bag',
#   {'entities': [[0, 5, 'Theme'],
#     [6, 9, 'Country/Region of Manufacture'],
#     [10, 16, 'Model'],
#     [17, 23, 'Brand'],
#     [24, 29, 'Product Line'],
#     [30, 35, 'Color'],
#     [36, 40, 'Color'],
#     [41, 48, 'Handle/Strap Material'],
#     [49, 55, 'Type'],
#     [56, 61, 'Type'],
#     [62, 71, 'Brand'],
#     [72, 75, 'Brand']]}],
#  ['LOUIS VUITTON Epi Serviette Fermoir Business Bag Brown M54358 LV Auth gt2071',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 17, 'Brand'],
#     [18, 27, 'Model'],
#     [28, 35, 'Brand'],
#     [36, 44, 'Occasion'],
#     [45, 48, 'Brand'],
#     [49, 54, 'Color'],
#     [55, 61, 'MPN'],
#     [62, 64, 'MPN'],
#     [65, 69, 'No Tag'],
#     [70, 76, 'No Tag']]}],
#  ['Womens Handbag', {'entities': [[0, 6, 'Department'], [7, 14, 'Type']]}],
#  ['Chanel Leo Lion Flap Bag Chevron Lambskin Medium',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 10, 'Model'],
#     [11, 15, 'Accents'],
#     [16, 20, 'Brand'],
#     [21, 24, 'Brand'],
#     [25, 32, 'Pattern'],
#     [33, 41, 'Material'],
#     [42, 48, 'Size']]}],
#  ['Gucci White " HoBo " Vintage Handbag Authenticated Two Tone " Genuine Leather "',
#   {'entities': [[0, 5, 'No Tag'],
#     [6, 11, 'Color'],
#     [21, 28, 'No Tag'],
#     [29, 36, 'Type'],
#     [37, 50, 'No Tag'],
#     [51, 54, 'No Tag'],
#     [55, 59, 'Color'],
#     [62, 69, 'No Tag'],
#     [70, 77, 'Trim Material']]}],
#  ['TUMI Women Voyageur Backpack Black Floral 15.5 " x12 .25 " 1100401041 TM-113',
#   {'entities': [[0, 4, 'Brand'],
#     [5, 10, 'Department'],
#     [11, 19, 'Model'],
#     [20, 28, 'Brand'],
#     [29, 34, 'Brand'],
#     [35, 41, 'Pattern'],
#     [42, 46, 'Measurement, dimension'],
#     [53, 56, 'Brand'],
#     [70, 76, 'MPN']]}],
#  ["Louis Vuitton Epi Marley MM M94615 Women 's Handbag , Shoulder Bag Fuchsia BF531772",
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 17, 'Brand'],
#     [18, 24, 'Model'],
#     [25, 27, 'Model'],
#     [28, 34, 'MPN'],
#     [35, 40, 'Department'],
#     [41, 43, 'Obscure'],
#     [44, 51, 'Type'],
#     [52, 53, 'Obscure'],
#     [54, 62, 'Brand'],
#     [63, 66, 'Brand'],
#     [67, 74, 'Color'],
#     [75, 83, 'MPN']]}],
#  ['Auth Louis Vuitton Monogram Josephine PM Blue Mini Lin Hand bag 0J130140n "',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 18, 'Brand'],
#     [19, 27, 'Pattern'],
#     [28, 37, 'Model'],
#     [38, 40, 'Model'],
#     [41, 45, 'Brand'],
#     [46, 50, 'Model'],
#     [51, 54, 'No Tag'],
#     [55, 59, 'Type'],
#     [60, 63, 'Brand'],
#     [64, 73, 'No Tag']]}],
#  ['Women \'s 16 " H Canvas Backpack Great Designs - Flower Native Owl Safari Dragonfly',
#   {'entities': [[0, 5, 'Department'],
#     [6, 8, 'Brand'],
#     [9, 11, 'Brand'],
#     [14, 15, 'No Tag'],
#     [16, 22, 'Obscure'],
#     [23, 31, 'Brand'],
#     [32, 37, 'No Tag'],
#     [38, 45, 'No Tag'],
#     [46, 47, 'Brand'],
#     [48, 54, 'Pattern'],
#     [55, 61, 'Theme'],
#     [62, 65, 'Pattern'],
#     [66, 72, 'Theme'],
#     [73, 82, 'Brand']]}],
#  ['GUCCI Logo GG Pattern Hand Tote Bag Canvas Leather Black Gold Italy 30SD226',
#   {'entities': [[0, 5, 'Pattern'],
#     [6, 10, 'Accents'],
#     [11, 13, 'Brand'],
#     [14, 21, 'Obscure'],
#     [22, 26, 'No Tag'],
#     [27, 31, 'Type'],
#     [32, 35, 'Brand'],
#     [36, 42, 'Fabric Type'],
#     [43, 50, 'Trim Material'],
#     [51, 56, 'Color'],
#     [57, 61, 'Hardware Material'],
#     [62, 67, 'Country/Region of Manufacture'],
#     [68, 75, 'MPN']]}],
#  ['LOUIS VUITTON MINI LOOPING HAND BAG DU2037 DAMIER EBENE N51158 SP ORDER 71057',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 18, 'Model'],
#     [19, 26, 'No Tag'],
#     [27, 31, 'Brand'],
#     [32, 35, 'Brand'],
#     [36, 42, 'No Tag'],
#     [43, 49, 'Product Line'],
#     [50, 55, 'Color'],
#     [56, 62, 'MPN'],
#     [63, 65, 'No Tag'],
#     [66, 71, 'No Tag'],
#     [72, 77, 'No Tag']]}],
#  ['SUMMER BEACH CANVAS TOTE BAGS WITH VARIOUS FLORAL PRINTED DESIGNS',
#   {'entities': [[0, 6, 'Season'],
#     [7, 12, 'Occasion'],
#     [13, 19, 'Fabric Type'],
#     [20, 24, 'Brand'],
#     [25, 29, 'Type'],
#     [30, 34, 'No Tag'],
#     [35, 42, 'No Tag'],
#     [43, 49, 'Brand'],
#     [50, 57, 'Features'],
#     [58, 65, 'No Tag']]}],
#  ['Louis Vuitton Lymington Bag ( New )',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Obscure'],
#     [14, 23, 'Model'],
#     [24, 27, 'Brand'],
#     [28, 29, 'No Tag'],
#     [30, 33, 'Country/Region of Manufacture'],
#     [34, 35, 'No Tag']]}],
#  ['Chanel Tote Bag Pink Canvas 2418819',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 11, 'Type'],
#     [12, 15, 'Type'],
#     [16, 20, 'Brand'],
#     [21, 27, 'Brand'],
#     [28, 35, 'No Tag']]}],
#  ['Women Boho Vintage Patchwork Ethnic Embroidered Clutch Bag Handmade Purse Wallet',
#   {'entities': [[0, 5, 'Department'],
#     [6, 10, 'Style'],
#     [11, 18, 'No Tag'],
#     [19, 28, 'Pattern'],
#     [29, 35, 'Style'],
#     [36, 47, 'Accents'],
#     [48, 54, 'Brand'],
#     [55, 58, 'Type'],
#     [59, 67, 'No Tag'],
#     [68, 73, 'Type'],
#     [74, 80, 'Type']]}],
#  ['LOUIS VUITTON Keepall 45 Travel Hand Bag Monogram Leather Brown M41428 68AC743',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 21, 'Product Line'],
#     [22, 24, 'Brand'],
#     [25, 31, 'Occasion'],
#     [32, 36, 'Type'],
#     [37, 40, 'Brand'],
#     [41, 49, 'Brand'],
#     [50, 57, 'Trim Material'],
#     [58, 63, 'Color'],
#     [64, 70, 'MPN'],
#     [71, 78, 'No Tag']]}],
#  ['Louis Vuitton Duomo Hobo in Damier Ebene w / Extra Shoulder Strap-100 % AUTHENTIC',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 19, 'Model'],
#     [20, 24, 'Type'],
#     [25, 27, 'No Tag'],
#     [28, 34, 'Product Line'],
#     [35, 40, 'Color'],
#     [41, 42, 'No Tag'],
#     [43, 44, 'No Tag'],
#     [45, 50, 'No Tag'],
#     [51, 59, 'Brand'],
#     [60, 69, 'No Tag'],
#     [70, 71, 'No Tag'],
#     [72, 81, 'No Tag']]}],
#  ['Authentic BURBERRY Vintage Leather Hand Bag Black D4382',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 18, 'Brand'],
#     [19, 26, 'No Tag'],
#     [27, 34, 'Brand'],
#     [35, 39, 'Features'],
#     [40, 43, 'Brand'],
#     [44, 49, 'Color'],
#     [50, 55, 'No Tag']]}],
#  ['Authentic New Louis Vuitton Pochette Monogram Kirigami Small Wallet Pouch',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 13, 'Country/Region of Manufacture'],
#     [14, 19, 'Brand'],
#     [20, 27, 'Brand'],
#     [28, 36, 'Model'],
#     [37, 45, 'Brand'],
#     [46, 54, 'Product Line'],
#     [55, 60, 'Obscure'],
#     [61, 67, 'Type'],
#     [68, 73, 'Type']]}],
#  ['VERY RARE & LIMITED EDITION AUTH CHRISTIAN DIOR LADY TWEED LARGE HANDBAG USED 2X',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 9, 'No Tag'],
#     [10, 11, 'Brand'],
#     [12, 19, 'No Tag'],
#     [20, 27, 'No Tag'],
#     [28, 32, 'No Tag'],
#     [33, 42, 'Brand'],
#     [43, 47, 'Brand'],
#     [48, 52, 'Product Line'],
#     [53, 58, 'Fabric Type'],
#     [59, 64, 'Brand'],
#     [65, 72, 'Type'],
#     [73, 77, 'No Tag'],
#     [78, 80, 'No Tag']]}],
#  ['Gucci In Italy Brown Tote Bag Ladies Brand Geniue Good Condition Used',
#   {'entities': [[0, 5, 'No Tag'],
#     [6, 8, 'Brand'],
#     [9, 14, 'Country/Region of Manufacture'],
#     [15, 20, 'Color'],
#     [21, 25, 'Type'],
#     [26, 29, 'Type'],
#     [30, 36, 'Department'],
#     [37, 42, 'Brand'],
#     [43, 49, 'No Tag'],
#     [50, 54, 'Model'],
#     [55, 64, 'No Tag'],
#     [65, 69, 'No Tag']]}],
#  ['STICKMAN LEATHER PURSE BAG CROSS BODY EUC',
#   {'entities': [[0, 8, 'Brand'],
#     [9, 16, 'Trim Material'],
#     [17, 22, 'Type'],
#     [23, 26, 'Brand'],
#     [27, 32, 'Brand'],
#     [33, 37, 'Brand'],
#     [38, 41, 'No Tag']]}],
#  ['Gold Lame Purse Vintage Evening Bag Gold Link Fold-in Handle',
#   {'entities': [[0, 4, 'Obscure'],
#     [5, 9, 'Color'],
#     [10, 15, 'Brand'],
#     [16, 23, 'No Tag'],
#     [24, 31, 'Occasion'],
#     [32, 35, 'Type'],
#     [36, 40, 'Color'],
#     [41, 45, 'Handle Style'],
#     [46, 53, 'Handle Style'],
#     [54, 60, 'No Tag']]}],
#  ["New Big Shoulder Cotton Hand Large Capacity Diagonal Travel Shopping Women 's Bag",
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 7, 'Size'],
#     [8, 16, 'Brand'],
#     [17, 23, 'Fabric Type'],
#     [24, 28, 'No Tag'],
#     [29, 34, 'Brand'],
#     [35, 43, 'No Tag'],
#     [44, 52, 'Pattern'],
#     [53, 59, 'Occasion'],
#     [60, 68, 'Type'],
#     [69, 74, 'Department'],
#     [75, 77, 'No Tag'],
#     [78, 81, 'Type']]}],
#  ['LOUIS VUITTON MONOGRAM NEO NOE ROSE w / MIRROR CHARM BALLERINE PINK CROSSBODY',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 22, 'Brand'],
#     [23, 26, 'Model'],
#     [27, 30, 'Brand'],
#     [31, 35, 'Color'],
#     [36, 37, 'No Tag'],
#     [38, 39, 'Handle/Strap Material'],
#     [40, 46, 'Features'],
#     [47, 52, 'Accents'],
#     [53, 62, 'Color'],
#     [63, 67, 'Color'],
#     [68, 77, 'Type']]}],
#  ['GUCCI Brown Leather Guccissima Trim Signoria Medium Sukey Tote Bag',
#   {'entities': [[0, 5, 'Pattern'],
#     [6, 11, 'Color'],
#     [12, 19, 'Handle/Strap Material'],
#     [20, 30, 'Product Line'],
#     [31, 35, 'Obscure'],
#     [36, 44, 'Model'],
#     [45, 51, 'Size'],
#     [52, 57, 'Product Line'],
#     [58, 62, 'Brand'],
#     [63, 66, 'Type']]}],
#  ['PRADA New-Vela 1BC167 Nylon Studded Crossbody Bag Black Green',
#   {'entities': [[0, 5, 'Brand'],
#     [6, 14, 'No Tag'],
#     [15, 21, 'No Tag'],
#     [22, 27, 'Brand'],
#     [28, 35, 'Accents'],
#     [36, 45, 'Type'],
#     [46, 49, 'Type'],
#     [50, 55, 'Color'],
#     [56, 61, 'Brand']]}],
#  ['CHANEL Quilted CC Single Chain Mini Shoulder Bag 1636342 Black Lambskin 60849',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 14, 'Accents'],
#     [15, 17, 'Accents'],
#     [18, 24, 'Handle Style'],
#     [25, 30, 'Obscure'],
#     [31, 35, 'Model'],
#     [36, 44, 'Brand'],
#     [45, 48, 'Type'],
#     [49, 56, 'No Tag'],
#     [57, 62, 'Color'],
#     [63, 71, 'Material'],
#     [72, 77, 'No Tag']]}],
#  ['Kate Spade Joeley Glitter Penny Large Top Zip Tote Handbag WKRU6278 Dusknavy',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 17, 'Model'],
#     [18, 25, 'Accents'],
#     [26, 31, 'No Tag'],
#     [32, 37, 'Brand'],
#     [38, 41, 'Style'],
#     [42, 45, 'Closure'],
#     [46, 50, 'Type'],
#     [51, 58, 'Type'],
#     [59, 67, 'MPN'],
#     [68, 76, 'No Tag']]}],
#  ['Travelon Anti-Theft Concealed Carry Hobo Bag Black',
#   {'entities': [[0, 8, 'Brand'],
#     [9, 19, 'Features'],
#     [20, 29, 'Pocket Type'],
#     [30, 35, 'Brand'],
#     [36, 40, 'Type'],
#     [41, 44, 'Brand'],
#     [45, 50, 'Color']]}],
#  ['Authentic Louis Vuitton Wild Animal Leopard Felicie Inserts ONLY',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 23, 'Brand'],
#     [24, 28, 'Pattern'],
#     [29, 35, 'No Tag'],
#     [36, 43, 'Brand'],
#     [44, 51, 'Model'],
#     [52, 59, 'Obscure'],
#     [60, 64, 'No Tag']]}],
#  ['Women Round Bag Shoulder 2022 Designer Fashion Leather Crossbody Messenger Bags',
#   {'entities': [[0, 5, 'Department'],
#     [6, 11, 'Style'],
#     [12, 15, 'Brand'],
#     [16, 24, 'Handle Style'],
#     [25, 29, 'No Tag'],
#     [30, 38, 'No Tag'],
#     [39, 46, 'Brand'],
#     [47, 54, 'Handle/Strap Material'],
#     [55, 64, 'Type'],
#     [65, 74, 'Type'],
#     [75, 79, 'Brand']]}],
#  ['NEW MICHAEL KORS NEWMAN BLACK PYTHON EMBOSSED LEATHER LG HOBO , SHOULDER , HAND BAG',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 11, 'Brand'],
#     [12, 16, 'Brand'],
#     [17, 23, 'Model'],
#     [24, 29, 'Pattern'],
#     [30, 36, 'Brand'],
#     [37, 45, 'Accents'],
#     [46, 53, 'Handle/Strap Material'],
#     [54, 56, 'Size'],
#     [57, 61, 'Type'],
#     [62, 63, 'No Tag'],
#     [64, 72, 'Handle Style'],
#     [73, 74, 'No Tag'],
#     [75, 79, 'Type'],
#     [80, 83, 'Brand']]}],
#  ['Women Small Messenger Cross Body Zip Shoulder Strap Bag Handbag - Geom Colorway',
#   {'entities': [[0, 5, 'Department'],
#     [6, 11, 'Brand'],
#     [12, 21, 'Type'],
#     [22, 27, 'Type'],
#     [28, 32, 'Type'],
#     [33, 36, 'Closure'],
#     [37, 45, 'Brand'],
#     [46, 51, 'Style'],
#     [52, 55, 'Type'],
#     [56, 63, 'Type'],
#     [64, 65, 'Brand'],
#     [66, 70, 'Pattern'],
#     [71, 79, 'No Tag']]}],
#  ['HOT ! * GUCCI GG Marmont Bambi Small Velvet Embroidered Shoulder Bag Crossbody NWT',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 5, 'No Tag'],
#     [6, 7, 'No Tag'],
#     [8, 13, 'Pattern'],
#     [14, 16, 'Product Line'],
#     [17, 24, 'Product Line'],
#     [25, 30, 'Model'],
#     [31, 36, 'Obscure'],
#     [37, 43, 'Material'],
#     [44, 55, 'Accents'],
#     [56, 64, 'Brand'],
#     [65, 68, 'Brand'],
#     [69, 78, 'Type'],
#     [79, 82, 'No Tag']]}],
#  ['AUTH CHRISTIAN DIOR 3 WAYS SHOULDER CROSSBODY HAND BAG RED LEATHER EMBOSS',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 14, 'Brand'],
#     [15, 19, 'Brand'],
#     [20, 21, 'Handle Style'],
#     [22, 26, 'Brand'],
#     [27, 35, 'Handle Style'],
#     [36, 45, 'Type'],
#     [46, 50, 'Type'],
#     [51, 54, 'Type'],
#     [55, 58, 'Color'],
#     [59, 66, 'Handle/Strap Material'],
#     [67, 73, 'Accents']]}],
#  ['Anthropologie Miss Albright Embroidered Zippered Clutch w / Tassel NWOT Purple',
#   {'entities': [[0, 13, 'Brand'],
#     [14, 18, 'Model'],
#     [19, 27, 'Brand'],
#     [28, 39, 'Accents'],
#     [40, 48, 'Closure'],
#     [49, 55, 'Type'],
#     [56, 57, 'No Tag'],
#     [58, 59, 'Handle/Strap Material'],
#     [60, 66, 'Brand'],
#     [67, 71, 'Obscure'],
#     [72, 78, 'Brand']]}],
#  ['EUC $ 1495 Tiffany & Co. foldover envelope bag day clutch crocodile leather black',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 5, 'No Tag'],
#     [6, 10, 'No Tag'],
#     [11, 18, 'Brand'],
#     [19, 20, 'No Tag'],
#     [21, 24, 'Brand'],
#     [25, 33, 'Features'],
#     [34, 42, 'Type'],
#     [43, 46, 'Type'],
#     [47, 50, 'Occasion'],
#     [51, 57, 'Brand'],
#     [58, 67, 'Pattern'],
#     [68, 75, 'Trim Material'],
#     [76, 81, 'Color']]}],
#  ['Authentic Louis Vuitton Monogram Pochette Gange Cross Body Bag M51870 LV Exc + +',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 23, 'Brand'],
#     [24, 32, 'Pattern'],
#     [33, 41, 'Model'],
#     [42, 47, 'Model'],
#     [48, 53, 'Type'],
#     [54, 58, 'Type'],
#     [59, 62, 'Type'],
#     [63, 69, 'MPN'],
#     [70, 72, 'Brand'],
#     [73, 76, 'No Tag'],
#     [77, 78, 'No Tag'],
#     [79, 80, 'Obscure']]}],
#  ['LOUIS VUITTON Giant Monogram Neverfull MM Khaki Green Beige Limited Edition , Box',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 19, 'Size'],
#     [20, 28, 'Pattern'],
#     [29, 38, 'Model'],
#     [39, 41, 'Model'],
#     [42, 47, 'Color'],
#     [48, 53, 'Color'],
#     [54, 59, 'Color'],
#     [60, 67, 'No Tag'],
#     [68, 75, 'No Tag'],
#     [76, 77, 'No Tag'],
#     [78, 81, 'No Tag']]}],
#  ["Fendi Mon Tresor Mini Shearling & Leather Bucket Bag Women 's Ns",
#   {'entities': [[0, 5, 'Brand'],
#     [6, 9, 'Model'],
#     [10, 16, 'Brand'],
#     [17, 21, 'Brand'],
#     [22, 31, 'Material'],
#     [32, 33, 'Obscure'],
#     [34, 41, 'Handle/Strap Material'],
#     [42, 48, 'Product Line'],
#     [49, 52, 'Type'],
#     [53, 58, 'Department'],
#     [59, 61, 'Brand'],
#     [62, 64, 'No Tag']]}],
#  ['CHANEL Matelasse Chain Flap Shoulder Bag Lamb Skin Black Gold CC Auth 26595',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 16, 'Pattern'],
#     [17, 22, 'Handle/Strap Material'],
#     [23, 27, 'Brand'],
#     [28, 36, 'Handle Style'],
#     [37, 40, 'Type'],
#     [41, 45, 'Material'],
#     [46, 50, 'Model'],
#     [51, 56, 'Brand'],
#     [57, 61, 'Hardware Material'],
#     [62, 64, 'Accents'],
#     [65, 69, 'No Tag'],
#     [70, 75, 'No Tag']]}],
#  ['AUTHENTIC TIMMY WOODS ASIAN DUCK AMAZING HAND CARVED MINAUDIERE PURSE BAG CLUTCH',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 21, 'Brand'],
#     [22, 27, 'Theme'],
#     [28, 32, 'Brand'],
#     [33, 40, 'No Tag'],
#     [41, 45, 'Brand'],
#     [46, 52, 'Brand'],
#     [53, 63, 'Style'],
#     [64, 69, 'Type'],
#     [70, 73, 'Brand'],
#     [74, 80, 'Type']]}],
#  ['Louis Vuitton Red Epi Speedy Limited Edition',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Obscure'],
#     [14, 17, 'Product Line'],
#     [18, 21, 'Brand'],
#     [22, 28, 'Brand'],
#     [29, 36, 'No Tag'],
#     [37, 44, 'No Tag']]}],
#  ['AUTHENTIC Louis Vuitton Limited Edition Epi Noe Marin Navy Leather Bag',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 23, 'Brand'],
#     [24, 31, 'No Tag'],
#     [32, 39, 'No Tag'],
#     [40, 43, 'Obscure'],
#     [44, 47, 'Brand'],
#     [48, 53, 'Brand'],
#     [54, 58, 'Obscure'],
#     [59, 66, 'Handle/Strap Material'],
#     [67, 70, 'Brand']]}],
#  ['Louis Vuitton My LV World Tour Monogram Speedy Bandouliere 30',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 16, 'Character Family'],
#     [17, 19, 'Brand'],
#     [20, 25, 'Model'],
#     [26, 30, 'Brand'],
#     [31, 39, 'Brand'],
#     [40, 46, 'Model'],
#     [47, 58, 'Type'],
#     [59, 61, 'Brand']]}],
#  ['US Dollar Clutch Purses Rhinestones Handbags Women Crystal Evening Bags Designer',
#   {'entities': [[0, 2, 'No Tag'],
#     [3, 9, 'Brand'],
#     [10, 16, 'Brand'],
#     [17, 23, 'Type'],
#     [24, 35, 'Accents'],
#     [36, 44, 'Type'],
#     [45, 50, 'Department'],
#     [51, 58, 'Brand'],
#     [59, 66, 'Occasion'],
#     [67, 71, 'Type'],
#     [72, 80, 'No Tag']]}],
#  ['CHANEL Double Flap 25 Quilted CC Logo Lambskin w / Chain Shoulder Bag Black / N0219',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 13, 'Accents'],
#     [14, 18, 'Brand'],
#     [19, 21, 'Measurement, dimension'],
#     [22, 29, 'Obscure'],
#     [30, 32, 'Accents'],
#     [33, 37, 'Brand'],
#     [38, 46, 'Material'],
#     [47, 48, 'No Tag'],
#     [49, 50, 'Handle/Strap Material'],
#     [51, 56, 'Handle/Strap Material'],
#     [57, 65, 'Handle Style'],
#     [66, 69, 'Type'],
#     [70, 75, 'Color'],
#     [76, 77, 'Handle/Strap Material'],
#     [78, 83, 'No Tag']]}],
#  ['LOUIS VUITTON Damier Ebene Brand New Tags 100 % Authentic Pochette',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 20, 'Brand'],
#     [21, 26, 'Color'],
#     [27, 32, 'No Tag'],
#     [33, 36, 'Model'],
#     [37, 41, 'No Tag'],
#     [42, 45, 'Obscure'],
#     [46, 47, 'No Tag'],
#     [48, 57, 'No Tag'],
#     [58, 66, 'Model']]}],
#  ['Auth LOUIS VUITTON Reade PM M91335 Indigo Monogram Vernis MI1014 Womens Handbag',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Product Line'],
#     [11, 18, 'Brand'],
#     [19, 24, 'Model'],
#     [25, 27, 'Brand'],
#     [28, 34, 'MPN'],
#     [35, 41, 'Color'],
#     [42, 50, 'Brand'],
#     [51, 57, 'Product Line'],
#     [58, 64, 'No Tag'],
#     [65, 71, 'Department'],
#     [72, 79, 'Type']]}],
#  ['New NWT Small Black Velvet Evening Bag Purse Pocketbook Clutch',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 7, 'No Tag'],
#     [8, 13, 'Brand'],
#     [14, 19, 'Color'],
#     [20, 26, 'Material'],
#     [27, 34, 'Occasion'],
#     [35, 38, 'Brand'],
#     [39, 44, 'Type'],
#     [45, 55, 'Type'],
#     [56, 62, 'Type']]}],
#  ['Authentic Louis Vuitton Speedy 40 Handbag w / Inside Organizer & Luggage Tag',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 23, 'Brand'],
#     [24, 30, 'Brand'],
#     [31, 33, 'Obscure'],
#     [34, 41, 'Type'],
#     [42, 43, 'No Tag'],
#     [44, 45, 'Handle/Strap Material'],
#     [46, 52, 'No Tag'],
#     [53, 62, 'Type'],
#     [63, 64, 'Brand'],
#     [65, 72, 'Type'],
#     [73, 76, 'No Tag']]}],
#  ['Loungefly Disney Beauty And The Beast Rose Mini Backpack & Wallet NWT',
#   {'entities': [[0, 9, 'Brand'],
#     [10, 16, 'Character Family'],
#     [17, 23, 'Character Family'],
#     [24, 27, 'Brand'],
#     [28, 31, 'No Tag'],
#     [32, 37, 'Brand'],
#     [38, 42, 'Brand'],
#     [43, 47, 'Model'],
#     [48, 56, 'Type'],
#     [57, 58, 'Brand'],
#     [59, 65, 'Type'],
#     [66, 69, 'No Tag']]}],
#  ['CHANEL Wallet On Chain ( woc ) In Black Caviar Leather - Gold Chain And Hardware',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 13, 'Type'],
#     [14, 16, 'Brand'],
#     [17, 22, 'Brand'],
#     [23, 24, 'No Tag'],
#     [25, 28, 'Type'],
#     [29, 30, 'No Tag'],
#     [31, 33, 'Model'],
#     [34, 39, 'Brand'],
#     [40, 46, 'Product Line'],
#     [47, 54, 'Handle/Strap Material'],
#     [55, 56, 'No Tag'],
#     [57, 61, 'Color'],
#     [62, 67, 'Obscure'],
#     [68, 71, 'Brand'],
#     [72, 80, 'No Tag']]}],
#  ['Raviani Lot Of 6 Coin Bags With Brindle Leather',
#   {'entities': [[0, 7, 'Brand'],
#     [8, 11, 'No Tag'],
#     [12, 14, 'Obscure'],
#     [15, 16, 'Obscure'],
#     [17, 21, 'No Tag'],
#     [22, 26, 'Type'],
#     [27, 31, 'No Tag'],
#     [32, 39, 'Obscure'],
#     [40, 47, 'Trim Material']]}],
#  ['CHANEL 21P Iridescent White WOC 19 Flap Bag Wallet On Chain Clutch Mini 17B Rose',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 10, 'Model'],
#     [11, 21, 'Accents'],
#     [22, 27, 'Color'],
#     [28, 31, 'Type'],
#     [32, 34, 'Model'],
#     [35, 39, 'Brand'],
#     [40, 43, 'Type'],
#     [44, 50, 'Type'],
#     [51, 53, 'Brand'],
#     [54, 59, 'Handle/Strap Material'],
#     [60, 66, 'Brand'],
#     [67, 71, 'Model'],
#     [72, 75, 'No Tag'],
#     [76, 80, 'Brand']]}],
#  ['Loungefly Disney Beauty and the Beast Rose Crossbody Faux Leather Bag',
#   {'entities': [[0, 9, 'Brand'],
#     [10, 16, 'Character Family'],
#     [17, 23, 'Character Family'],
#     [24, 27, 'Brand'],
#     [28, 31, 'No Tag'],
#     [32, 37, 'Brand'],
#     [38, 42, 'Brand'],
#     [43, 52, 'Type'],
#     [53, 57, 'Material'],
#     [58, 65, 'Handle/Strap Material'],
#     [66, 69, 'Brand']]}],
#  ['Authentic GOYARD Bag MM # 270-003-566-0344',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 16, 'Brand'],
#     [17, 20, 'Type'],
#     [21, 23, 'Brand'],
#     [24, 25, 'No Tag'],
#     [26, 42, 'No Tag']]}],
#  ['Louis Vuitton Tressage Tote Monogram Handbag SS 2017 Two Way Reverse M44113',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 22, 'Model'],
#     [23, 27, 'Brand'],
#     [28, 36, 'Pattern'],
#     [37, 44, 'Type'],
#     [45, 47, 'No Tag'],
#     [48, 52, 'Obscure'],
#     [53, 56, 'No Tag'],
#     [57, 60, 'Brand'],
#     [61, 68, 'Style'],
#     [69, 75, 'MPN']]}],
#  ['BALENCIAGA Mini Neo Classic City Croc Embossed Leather Top Handle Bag',
#   {'entities': [[0, 10, 'Brand'],
#     [11, 15, 'Brand'],
#     [16, 19, 'Brand'],
#     [20, 27, 'Model'],
#     [28, 32, 'Model'],
#     [33, 37, 'Brand'],
#     [38, 46, 'Brand'],
#     [47, 54, 'Handle/Strap Material'],
#     [55, 58, 'No Tag'],
#     [59, 65, 'Handle Style'],
#     [66, 69, 'Brand']]}],
#  ['Louis Vuitton Monogram Shoulder Bag 3 pieces set 527800',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 22, 'Pattern'],
#     [23, 31, 'Brand'],
#     [32, 35, 'Brand'],
#     [36, 37, 'Features'],
#     [38, 44, 'No Tag'],
#     [45, 48, 'No Tag'],
#     [49, 55, 'No Tag']]}],
#  ['Fila Crossbody / Mini Bag',
#   {'entities': [[0, 4, 'Brand'],
#     [5, 14, 'Type'],
#     [15, 16, 'Handle/Strap Material'],
#     [17, 21, 'Size'],
#     [22, 25, 'Brand']]}],
#  ['Laurel Burch Aquatic Horses Blue Purple Beige Canvas Cosmetic Zipper Bag NWT',
#   {'entities': [[0, 6, 'Model'],
#     [7, 12, 'Brand'],
#     [13, 20, 'Brand'],
#     [21, 27, 'Brand'],
#     [28, 32, 'Color'],
#     [33, 39, 'Product Line'],
#     [40, 45, 'Color'],
#     [46, 52, 'Fabric Type'],
#     [53, 61, 'Type'],
#     [62, 68, 'Closure'],
#     [69, 72, 'Brand'],
#     [73, 76, 'No Tag']]}],
#  ['Brand New CHANEL Jersey Fabric Quilted Foldable Tote With Chain Black Multicolor',
#   {'entities': [[0, 5, 'No Tag'],
#     [6, 9, 'Country/Region of Manufacture'],
#     [10, 16, 'Brand'],
#     [17, 23, 'Model'],
#     [24, 30, 'No Tag'],
#     [31, 38, 'Accents'],
#     [39, 47, 'Features'],
#     [48, 52, 'Type'],
#     [53, 57, 'No Tag'],
#     [58, 63, 'Handle/Strap Material'],
#     [64, 69, 'Brand'],
#     [70, 80, 'Color']]}],
#  ['Old Trend Sprout Land Vintage Retro Burgundy Distress Leather Tote Bag',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 9, 'No Tag'],
#     [10, 16, 'Brand'],
#     [17, 21, 'Brand'],
#     [22, 29, 'No Tag'],
#     [30, 35, 'Style'],
#     [36, 44, 'Color'],
#     [45, 53, 'Features'],
#     [54, 61, 'Trim Material'],
#     [62, 66, 'Type'],
#     [67, 70, 'Brand']]}],
#  ['Auth LOUIS VUITTON Amfar Three Vanity Star Shoulder Bag Monogram M47275 13BS102',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 18, 'Brand'],
#     [19, 24, 'Model'],
#     [25, 30, 'Brand'],
#     [31, 37, 'Style'],
#     [38, 42, 'Character Family'],
#     [43, 51, 'Handle Style'],
#     [52, 55, 'Type'],
#     [56, 64, 'Brand'],
#     [65, 71, 'MPN'],
#     [72, 79, 'No Tag']]}],
#  ['NWT Brahmin Marianna Leather Tote / Shoulder Bag in Pearl Summer Dalton',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 11, 'Brand'],
#     [12, 20, 'Model'],
#     [21, 28, 'Material'],
#     [29, 33, 'Type'],
#     [34, 35, 'Obscure'],
#     [36, 44, 'Brand'],
#     [45, 48, 'Type'],
#     [49, 51, 'No Tag'],
#     [52, 57, 'Accents'],
#     [58, 64, 'Season'],
#     [65, 71, 'Color']]}],
#  ['BRIGHTON BRITTA TIVOLI TRELLIS 3D FLORAL BEADED CROSSBODY SHOULDER HANDBAG $ 310',
#   {'entities': [[0, 8, 'Brand'],
#     [9, 15, 'Model'],
#     [16, 22, 'Model'],
#     [23, 30, 'Brand'],
#     [31, 33, 'Features'],
#     [34, 40, 'Pattern'],
#     [41, 47, 'Accents'],
#     [48, 57, 'Type'],
#     [58, 66, 'Handle Style'],
#     [67, 74, 'Type'],
#     [75, 76, 'No Tag'],
#     [77, 80, 'No Tag']]}],
#  ['LOUIS VUITTON SAINT CLOUD GM SHOULDER BAG PURSE M51242 TH0994 70422',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 19, 'Brand'],
#     [20, 25, 'Brand'],
#     [26, 28, 'Model'],
#     [29, 37, 'Handle Style'],
#     [38, 41, 'Brand'],
#     [42, 47, 'Type'],
#     [48, 54, 'MPN'],
#     [55, 61, 'Brand'],
#     [62, 67, 'No Tag']]}],
#  ['Women Luxury Jelly Bag Polishing Leather Shoulder Handbag Crossbody Tote Shell',
#   {'entities': [[0, 5, 'Department'],
#     [6, 12, 'Theme'],
#     [13, 18, 'Material'],
#     [19, 22, 'Brand'],
#     [23, 32, 'Fabric Type'],
#     [33, 40, 'Obscure'],
#     [41, 49, 'Brand'],
#     [50, 57, 'Type'],
#     [58, 67, 'Type'],
#     [68, 72, 'Type'],
#     [73, 78, 'Accents']]}],
#  ['Vera Bradley Small Trimmed Vera Shoulder Bag / Tote in Paisley Amethyst . NWT',
#   {'entities': [[0, 4, 'Obscure'],
#     [5, 12, 'Brand'],
#     [13, 18, 'Brand'],
#     [19, 26, 'Features'],
#     [27, 31, 'Obscure'],
#     [32, 40, 'Handle Style'],
#     [41, 44, 'Brand'],
#     [45, 46, 'Handle/Strap Material'],
#     [47, 51, 'Type'],
#     [52, 54, 'Brand'],
#     [55, 62, 'Accents'],
#     [63, 71, 'Color'],
#     [72, 73, 'No Tag'],
#     [74, 77, 'No Tag']]}],
#  ['QE2 VINTAGE CANVAS TOTE BAG . NEW , NEVER USED . SIZE TOP TO BOTTOM 18 " W12 "',
#   {'entities': [[0, 3, 'Model'],
#     [4, 11, 'No Tag'],
#     [12, 18, 'Brand'],
#     [19, 23, 'Brand'],
#     [24, 27, 'Type'],
#     [28, 29, 'Obscure'],
#     [30, 33, 'Brand'],
#     [34, 35, 'Obscure'],
#     [36, 41, 'No Tag'],
#     [42, 46, 'No Tag'],
#     [47, 48, 'No Tag'],
#     [49, 53, 'No Tag'],
#     [54, 57, 'No Tag'],
#     [58, 60, 'Model'],
#     [61, 67, 'No Tag'],
#     [68, 70, 'Measurement, dimension']]}],
#  ['Urban Expressions Women \'s Clutch Shoulder Bag in Pink 11.25 " x6 "',
#   {'entities': [[0, 5, 'Model'],
#     [6, 17, 'Brand'],
#     [18, 23, 'Department'],
#     [24, 26, 'Brand'],
#     [27, 33, 'Type'],
#     [34, 42, 'Handle Style'],
#     [43, 46, 'Brand'],
#     [47, 49, 'Obscure'],
#     [50, 54, 'Brand'],
#     [55, 60, 'Measurement, dimension'],
#     [63, 65, 'Brand']]}],
#  ['Fossil Women \'s " Sydney " Fringe Crossbody Bag Style # : ZB6707661',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 12, 'Department'],
#     [13, 15, 'Brand'],
#     [18, 24, 'Model'],
#     [27, 33, 'Brand'],
#     [34, 43, 'Type'],
#     [44, 47, 'Type'],
#     [48, 53, 'Brand'],
#     [54, 55, 'No Tag'],
#     [56, 57, 'No Tag'],
#     [58, 67, 'MPN']]}],
#  ['VALENTINO SHOULDER BAG , SMALL',
#   {'entities': [[0, 9, 'Brand'],
#     [10, 18, 'Handle Style'],
#     [19, 22, 'Type'],
#     [23, 24, 'No Tag'],
#     [25, 30, 'Size']]}],
#  ['GUCCI Logo Bamboo Hand Tote Bag Leather Brown Gold-Plated Made In Italy 01MQ835',
#   {'entities': [[0, 5, 'Pattern'],
#     [6, 10, 'Accents'],
#     [11, 17, 'Handle/Strap Material'],
#     [18, 22, 'Features'],
#     [23, 27, 'Type'],
#     [28, 31, 'Type'],
#     [32, 39, 'Handle/Strap Material'],
#     [40, 45, 'Color'],
#     [46, 57, 'Hardware Material'],
#     [58, 62, 'No Tag'],
#     [63, 65, 'No Tag'],
#     [66, 71, 'Country/Region of Manufacture'],
#     [72, 79, 'MPN']]}],
#  ['NEW CAROLINA HERRERA ANDY 7 HANDBAG 100 % AUTHENTIC ** FREE SHIPPING **',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 12, 'Brand'],
#     [13, 20, 'Brand'],
#     [21, 25, 'Model'],
#     [26, 27, 'No Tag'],
#     [28, 35, 'Type'],
#     [36, 39, 'No Tag'],
#     [40, 41, 'Obscure'],
#     [42, 51, 'No Tag'],
#     [52, 54, 'No Tag'],
#     [55, 59, 'No Tag'],
#     [60, 68, 'No Tag'],
#     [69, 71, 'No Tag']]}],
#  ['Used Louis Vuitton t120529 Shoulder bag Saint Cloud GM M51242',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 18, 'Brand'],
#     [19, 26, 'No Tag'],
#     [27, 35, 'Handle Style'],
#     [36, 39, 'Type'],
#     [40, 45, 'Brand'],
#     [46, 51, 'Style'],
#     [52, 54, 'Model'],
#     [55, 61, 'MPN']]}],
#  ['Auth LOUIS VUITTON PAPILLON 26 Hand Bag Monogram Leather Brown M51366 37BT472',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 18, 'Brand'],
#     [19, 27, 'Model'],
#     [28, 30, 'No Tag'],
#     [31, 35, 'Type'],
#     [36, 39, 'Brand'],
#     [40, 48, 'Brand'],
#     [49, 56, 'Trim Material'],
#     [57, 62, 'Color'],
#     [63, 69, 'MPN'],
#     [70, 77, 'Brand']]}],
#  ['Premium Solid Color PU Leather Turnlock Flap Clutch Bag Handbag - Diff Colors',
#   {'entities': [[0, 7, 'No Tag'],
#     [8, 13, 'No Tag'],
#     [14, 19, 'Brand'],
#     [20, 22, 'Material'],
#     [23, 30, 'Trim Material'],
#     [31, 39, 'Closure'],
#     [40, 44, 'Brand'],
#     [45, 51, 'Type'],
#     [52, 55, 'Type'],
#     [56, 63, 'Type'],
#     [64, 65, 'Brand'],
#     [66, 70, 'No Tag'],
#     [71, 77, 'No Tag']]}],
#  ['LOUIS VUITTON CITY STEAMER GRIS BLACK HANDBAG MM',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 18, 'Product Line'],
#     [19, 26, 'Brand'],
#     [27, 31, 'Color'],
#     [32, 37, 'Pattern'],
#     [38, 45, 'Type'],
#     [46, 48, 'Brand']]}],
#  ['New Vera Bradley Lunch Bunch Lunch Bag In Plum Crazy',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 8, 'Brand'],
#     [9, 16, 'Brand'],
#     [17, 22, 'Features'],
#     [23, 28, 'Brand'],
#     [29, 34, 'Model'],
#     [35, 38, 'Brand'],
#     [39, 41, 'Model'],
#     [42, 46, 'Color'],
#     [47, 52, 'Color']]}],
#  ['Authentic PRADA Nylon Backpack Black 0340A',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 21, 'Lining Material'],
#     [22, 30, 'Brand'],
#     [31, 36, 'Brand'],
#     [37, 42, 'MPN']]}],
#  ['Louis Vuitton Neverfull MM Lovelock Monogram M44364 Tote Bag Brown Multi-color',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 23, 'Brand'],
#     [24, 26, 'Brand'],
#     [27, 35, 'Closure'],
#     [36, 44, 'Brand'],
#     [45, 51, 'MPN'],
#     [52, 56, 'Type'],
#     [57, 60, 'Type'],
#     [61, 66, 'Color'],
#     [67, 78, 'Color']]}],
#  ['Coach Signature Stripe PVC Satchel Crossbody . F24362 Khaki / Mulberry NWT',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 15, 'Accents'],
#     [16, 22, 'Brand'],
#     [23, 26, 'Material'],
#     [27, 34, 'Type'],
#     [35, 44, 'Type'],
#     [45, 46, 'No Tag'],
#     [47, 53, 'MPN'],
#     [54, 59, 'Color'],
#     [60, 61, 'Handle/Strap Material'],
#     [62, 70, 'Brand'],
#     [71, 74, 'No Tag']]}],
#  ['Anello Japan Small 2way Shoulder Bag Carry Case Navy AT-H0851',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 12, 'Country/Region of Manufacture'],
#     [13, 18, 'Brand'],
#     [19, 23, 'Features'],
#     [24, 32, 'Handle Style'],
#     [33, 36, 'Type'],
#     [37, 42, 'Brand'],
#     [43, 47, 'Obscure'],
#     [48, 52, 'Obscure'],
#     [53, 61, 'MPN']]}],
#  ['NWT FURLA Avio Scuro / Dark Blue Leather M Milano Tote Bag $ 478 - Made in Italy',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 9, 'Brand'],
#     [10, 14, 'Model'],
#     [15, 20, 'Brand'],
#     [21, 22, 'No Tag'],
#     [23, 27, 'Color'],
#     [28, 32, 'Brand'],
#     [33, 40, 'Handle/Strap Material'],
#     [41, 42, 'No Tag'],
#     [43, 49, 'Country/Region of Manufacture'],
#     [50, 54, 'Brand'],
#     [55, 58, 'Brand'],
#     [59, 60, 'No Tag'],
#     [61, 64, 'No Tag'],
#     [65, 66, 'Brand'],
#     [67, 71, 'No Tag'],
#     [72, 74, 'No Tag'],
#     [75, 80, 'Country/Region of Manufacture']]}],
#  ['Women Mobile Cell Phone Bag Cross body Shoulder Bag Long Clutch Wallet Black US',
#   {'entities': [[0, 5, 'Department'],
#     [6, 12, 'Brand'],
#     [13, 17, 'Brand'],
#     [18, 23, 'Features'],
#     [24, 27, 'Type'],
#     [28, 33, 'Type'],
#     [34, 38, 'Brand'],
#     [39, 47, 'Handle Style'],
#     [48, 51, 'Type'],
#     [52, 56, 'Handle Drop'],
#     [57, 63, 'Brand'],
#     [64, 70, 'Type'],
#     [71, 76, 'Color'],
#     [77, 79, 'Obscure']]}],
#  ['Auth LOUIS VUITTON Multicolor Speedy 30 Boston Bag M92642 Noir Black / 059116',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 18, 'Brand'],
#     [19, 29, 'Color'],
#     [30, 36, 'Model'],
#     [37, 39, 'Model'],
#     [40, 46, 'Product Line'],
#     [47, 50, 'Type'],
#     [51, 57, 'MPN'],
#     [58, 62, 'Color'],
#     [63, 68, 'Brand'],
#     [69, 70, 'No Tag'],
#     [71, 77, 'No Tag']]}],
#  ['Chanel Vintage Square Classic Single Flap Bag Quilted Lambskin Mini',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 14, 'No Tag'],
#     [15, 21, 'Type'],
#     [22, 29, 'Model'],
#     [30, 36, 'No Tag'],
#     [37, 41, 'Type'],
#     [42, 45, 'Brand'],
#     [46, 53, 'Obscure'],
#     [54, 62, 'Material'],
#     [63, 67, 'Brand']]}],
#  ['New Radley London Abbotsford open top leather grab bag leather black Gold',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 10, 'Brand'],
#     [11, 17, 'Brand'],
#     [18, 28, 'Model'],
#     [29, 33, 'Closure'],
#     [34, 37, 'Closure'],
#     [38, 45, 'Handle/Strap Material'],
#     [46, 50, 'No Tag'],
#     [51, 54, 'Type'],
#     [55, 62, 'Handle/Strap Material'],
#     [63, 68, 'Color'],
#     [69, 73, 'Color']]}],
#  ['GOYARD - PINK MONTE CARLO MM - RARE - MIAMI EXCLUSIVE - CROSSBODY BAG - CLUTCH',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 8, 'Brand'],
#     [9, 13, 'Brand'],
#     [14, 19, 'Model'],
#     [20, 25, 'Brand'],
#     [26, 28, 'Model'],
#     [29, 30, 'Brand'],
#     [31, 35, 'No Tag'],
#     [36, 37, 'No Tag'],
#     [38, 43, 'No Tag'],
#     [44, 53, 'No Tag'],
#     [54, 55, 'No Tag'],
#     [56, 65, 'Type'],
#     [66, 69, 'Type'],
#     [70, 71, 'Brand'],
#     [72, 78, 'Type']]}],
#  ['Bottega Veneta RARE Navy Blue Velvet Butterfly Pouch Clutch Pochette Bag w / Box',
#   {'entities': [[0, 7, 'Brand'],
#     [8, 14, 'Brand'],
#     [15, 19, 'No Tag'],
#     [20, 24, 'Color'],
#     [25, 29, 'Color'],
#     [30, 36, 'Fabric Type'],
#     [37, 46, 'Brand'],
#     [47, 52, 'Type'],
#     [53, 59, 'Type'],
#     [60, 68, 'Model'],
#     [69, 72, 'Brand'],
#     [73, 74, 'No Tag'],
#     [75, 76, 'No Tag'],
#     [77, 80, 'Obscure']]}],
#  ['NWT ! Michael Kors Devon Large Calf Leather Satchel / Shoulder Tote in Steel Blue',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 5, 'No Tag'],
#     [6, 13, 'Brand'],
#     [14, 18, 'Brand'],
#     [19, 24, 'No Tag'],
#     [25, 30, 'Brand'],
#     [31, 35, 'Material'],
#     [36, 43, 'Handle/Strap Material'],
#     [44, 51, 'Type'],
#     [52, 53, 'Handle/Strap Material'],
#     [54, 62, 'Brand'],
#     [63, 67, 'Brand'],
#     [68, 70, 'No Tag'],
#     [71, 76, 'Color'],
#     [77, 81, 'Brand']]}],
#  ['Louis Vuitton Nomade Camel Document Case Japan 20th Anniversary1998 6J250060N "',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Obscure'],
#     [14, 20, 'Obscure'],
#     [21, 26, 'Color'],
#     [27, 35, 'Obscure'],
#     [36, 40, 'Type'],
#     [41, 46, 'No Tag'],
#     [47, 51, 'Obscure'],
#     [52, 67, 'Obscure'],
#     [68, 77, 'Obscure']]}],
#  ['Auth Louis Vuitton Monogram Pochette Dame Clutch Bag Vintage 9J220010n "',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Product Line'],
#     [11, 18, 'Obscure'],
#     [19, 27, 'Brand'],
#     [28, 36, 'Product Line'],
#     [37, 41, 'Model'],
#     [42, 48, 'Brand'],
#     [49, 52, 'Brand'],
#     [53, 60, 'No Tag'],
#     [61, 70, 'MPN']]}],
#  ['Five Pack Black 40 " Woven Garment Bags Breathable Storage Suits Dresses Travel',
#   {'entities': [[5, 9, 'Brand'],
#     [10, 15, 'Brand'],
#     [16, 18, 'Brand'],
#     [21, 26, 'Obscure'],
#     [27, 34, 'Obscure'],
#     [35, 39, 'Obscure'],
#     [40, 50, 'Obscure'],
#     [51, 58, 'Obscure'],
#     [59, 64, 'Obscure'],
#     [65, 72, 'Obscure'],
#     [73, 79, 'Occasion']]}],
#  ['FENDI Zucca Backpack Bag Coating Canvas Brown Black Gold Hardware 8BZ038 V-8250',
#   {'entities': [[0, 5, 'Brand'],
#     [6, 11, 'Brand'],
#     [12, 20, 'Brand'],
#     [21, 24, 'Brand'],
#     [25, 32, 'Fabric Type'],
#     [33, 39, 'Obscure'],
#     [40, 45, 'Color'],
#     [46, 51, 'Color'],
#     [52, 56, 'Obscure'],
#     [57, 65, 'No Tag'],
#     [66, 72, 'MPN'],
#     [73, 79, 'No Tag']]}],
#  ['Women Fashion Leather Leopard Print Clutch Handbag Chain Shoulder Crossbody Bag',
#   {'entities': [[0, 5, 'Department'],
#     [6, 13, 'Brand'],
#     [14, 21, 'Handle/Strap Material'],
#     [22, 29, 'Pattern'],
#     [30, 35, 'No Tag'],
#     [36, 42, 'Type'],
#     [43, 50, 'Type'],
#     [51, 56, 'Handle/Strap Material'],
#     [57, 65, 'Handle Style'],
#     [66, 75, 'Type'],
#     [76, 79, 'Brand']]}],
#  ['- GUCCI tote bag leather Browne total handle',
#   {'entities': [[0, 1, 'No Tag'],
#     [2, 7, 'Brand'],
#     [8, 12, 'Brand'],
#     [13, 16, 'Brand'],
#     [17, 24, 'Trim Material'],
#     [25, 31, 'Color'],
#     [32, 37, 'Handle Style'],
#     [38, 44, 'Handle Style']]}],
#  ['CHANEL Chain Shoulder Bag Calfskin leather felt Green Used Women SHW logo CC',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 12, 'Handle/Strap Material'],
#     [13, 21, 'Brand'],
#     [22, 25, 'Brand'],
#     [26, 34, 'Material'],
#     [35, 42, 'Brand'],
#     [43, 47, 'Brand'],
#     [48, 53, 'Color'],
#     [54, 58, 'No Tag'],
#     [59, 64, 'Department'],
#     [65, 68, 'No Tag'],
#     [69, 73, 'Accents'],
#     [74, 76, 'Model']]}],
#  ['Valentino Rockstud Spike Small Shoulder Bag - Choose color',
#   {'entities': [[0, 9, 'Brand'],
#     [10, 18, 'Accents'],
#     [19, 24, 'Brand'],
#     [25, 30, 'Size'],
#     [31, 39, 'Brand'],
#     [40, 43, 'Brand'],
#     [44, 45, 'No Tag'],
#     [46, 52, 'No Tag'],
#     [53, 58, 'No Tag']]}],
#  ['Louis Vuitton My Lockme BB Light Blue Leather Chain Bag 100 % Authentic',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 16, 'Character Family'],
#     [17, 23, 'Brand'],
#     [24, 26, 'Model'],
#     [27, 32, 'Color'],
#     [33, 37, 'Brand'],
#     [38, 45, 'Handle/Strap Material'],
#     [46, 51, 'Obscure'],
#     [52, 55, 'Type'],
#     [56, 59, 'No Tag'],
#     [60, 61, 'No Tag'],
#     [62, 71, 'No Tag']]}],
#  ['Givenchy Parfums Silver Tote',
#   {'entities': [[0, 8, 'Brand'],
#     [9, 16, 'No Tag'],
#     [17, 23, 'Color'],
#     [24, 28, 'Brand']]}],
#  ['Furla Rialto Ladies Large Dark Red Grain Leather Hobo Bag 977641',
#   {'entities': [[0, 5, 'Brand'],
#     [6, 12, 'Model'],
#     [13, 19, 'Department'],
#     [20, 25, 'Pocket Type'],
#     [26, 30, 'Color'],
#     [31, 34, 'Product Line'],
#     [35, 40, 'Material'],
#     [41, 48, 'Handle/Strap Material'],
#     [49, 53, 'Type'],
#     [54, 57, 'Type'],
#     [58, 64, 'No Tag']]}],
#  ['Coach Purse Multi Color Signature C Satin Cross body #E 1076-F15187 Authentic Bag',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 11, 'Brand'],
#     [12, 17, 'Pocket Type'],
#     [18, 23, 'Color'],
#     [24, 33, 'Pattern'],
#     [34, 35, 'Brand'],
#     [36, 41, 'Material'],
#     [42, 47, 'Type'],
#     [48, 52, 'Brand'],
#     [53, 55, 'No Tag'],
#     [56, 67, 'No Tag'],
#     [68, 77, 'No Tag'],
#     [78, 81, 'Type']]}],
#  ['Louis Vuitton Speedy Bandouliere 22 Black Gold Chain Handle Crossbody Bag M58631',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 20, 'Brand'],
#     [21, 32, 'Type'],
#     [33, 35, 'Measurement, dimension'],
#     [36, 41, 'Color'],
#     [42, 46, 'Color'],
#     [47, 52, 'Handle/Strap Material'],
#     [53, 59, 'No Tag'],
#     [60, 69, 'Type'],
#     [70, 73, 'Brand'],
#     [74, 80, 'MPN']]}],
#  ['Kate Spade Lilah Laurel Way Black Crossbody Shoulder Bag Purse WKRU3932 $ 379',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 16, 'Model'],
#     [17, 23, 'Pattern'],
#     [24, 27, 'No Tag'],
#     [28, 33, 'Color'],
#     [34, 43, 'Brand'],
#     [44, 52, 'Handle Style'],
#     [53, 56, 'Type'],
#     [57, 62, 'Type'],
#     [63, 71, 'MPN'],
#     [72, 73, 'No Tag'],
#     [74, 77, 'No Tag']]}],
#  ['Tignanello White / Blue Leather Small Messenger Crossbody / Shoulder Bag Purse',
#   {'entities': [[0, 10, 'Brand'],
#     [11, 16, 'Color'],
#     [17, 18, 'Handle/Strap Material'],
#     [19, 23, 'Color'],
#     [24, 31, 'Trim Material'],
#     [32, 37, 'Obscure'],
#     [38, 47, 'Type'],
#     [48, 57, 'Type'],
#     [58, 59, 'No Tag'],
#     [60, 68, 'Type'],
#     [69, 72, 'Brand'],
#     [73, 78, 'Brand']]}],
#  ['Authentic FENDI Shoulder Hand Bag Suede Leather Brown C3799',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 24, 'Brand'],
#     [25, 29, 'Features'],
#     [30, 33, 'Type'],
#     [34, 39, 'Brand'],
#     [40, 47, 'Handle/Strap Material'],
#     [48, 53, 'Color'],
#     [54, 59, 'No Tag']]}],
#  ['BURBERRY LEATHER HAYMARKET TOTE TOGGLE PURSE BAG AUTHENTIC RED',
#   {'entities': [[0, 8, 'Brand'],
#     [9, 16, 'Trim Material'],
#     [17, 26, 'Product Line'],
#     [27, 31, 'Brand'],
#     [32, 38, 'Accents'],
#     [39, 44, 'Brand'],
#     [45, 48, 'Brand'],
#     [49, 58, 'No Tag'],
#     [59, 62, 'Color']]}],
#  ['100 % Authentic Louis Vuitton Speedy 30 Multicolor Hand Bag',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 5, 'No Tag'],
#     [6, 15, 'No Tag'],
#     [16, 21, 'Brand'],
#     [22, 29, 'Obscure'],
#     [30, 36, 'Model'],
#     [37, 39, 'Brand'],
#     [40, 50, 'Color'],
#     [51, 55, 'No Tag'],
#     [56, 59, 'Type']]}],
#  ['Chanel Lady Braid Shopping Tote Quilted Distressed Lambskin Medium',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 11, 'Department'],
#     [12, 17, 'Fabric Type'],
#     [18, 26, 'Brand'],
#     [27, 31, 'Brand'],
#     [32, 39, 'Features'],
#     [40, 50, 'Fabric Type'],
#     [51, 59, 'Material'],
#     [60, 66, 'Size']]}],
#  ['Justin West Rhinestone Buckle Western Floral Scroll Conceal Carry Handbag Purse',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 11, 'Brand'],
#     [12, 22, 'Accents'],
#     [23, 29, 'Closure'],
#     [30, 37, 'Style'],
#     [38, 44, 'Accents'],
#     [45, 51, 'No Tag'],
#     [52, 59, 'Product Line'],
#     [60, 65, 'Type'],
#     [66, 73, 'Type'],
#     [74, 79, 'Brand']]}],
#  ['Elephant Fabric Woven Handmade Purse Thai style colorful pattern animal Charm',
#   {'entities': [[0, 8, 'No Tag'],
#     [9, 15, 'Brand'],
#     [16, 21, 'Brand'],
#     [22, 30, 'Features'],
#     [31, 36, 'Type'],
#     [37, 41, 'Country/Region of Manufacture'],
#     [42, 47, 'No Tag'],
#     [48, 56, 'Obscure'],
#     [57, 64, 'No Tag'],
#     [65, 71, 'Pattern'],
#     [72, 77, 'Accents']]}],
#  ['Chanel Shoulder Bag Black Leather 1731367',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 15, 'Handle Style'],
#     [16, 19, 'Type'],
#     [20, 25, 'Brand'],
#     [26, 33, 'Brand'],
#     [34, 41, 'No Tag']]}],
#  ['Auth Gucci GG canvas Shoulder bag canvas Black red From Japan 0828 * 2749',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 13, 'Brand'],
#     [14, 20, 'Fabric Type'],
#     [21, 29, 'Handle Style'],
#     [30, 33, 'Type'],
#     [34, 40, 'Brand'],
#     [41, 46, 'Color'],
#     [47, 50, 'Color'],
#     [51, 55, 'No Tag'],
#     [56, 61, 'No Tag'],
#     [62, 66, 'Obscure'],
#     [67, 68, 'No Tag'],
#     [69, 73, 'Obscure']]}],
#  ['❤ BRAHMIN MINI ASHER BALI + WALLET BUTTER CHAMPAGNE GOLD TASSEL CROC LEATHER ❤',
#   {'entities': [[0, 1, 'No Tag'],
#     [2, 9, 'Brand'],
#     [10, 14, 'Brand'],
#     [15, 20, 'Model'],
#     [21, 25, 'Style'],
#     [26, 27, 'Obscure'],
#     [28, 34, 'Type'],
#     [35, 41, 'Color'],
#     [42, 51, 'Color'],
#     [52, 56, 'Hardware Material'],
#     [57, 63, 'Accents'],
#     [64, 68, 'Pattern'],
#     [69, 76, 'Trim Material'],
#     [77, 78, 'No Tag']]}],
#  ['Authentic Louis Vuitton Epi Lussac Shoulder Bag Yellow M52289 LV D6280',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 23, 'Brand'],
#     [24, 27, 'Material'],
#     [28, 34, 'Model'],
#     [35, 43, 'Handle Style'],
#     [44, 47, 'Brand'],
#     [48, 54, 'Color'],
#     [55, 61, 'MPN'],
#     [62, 64, 'MPN'],
#     [65, 70, 'No Tag']]}],
#  ['Louis Vuitton Love Lock Heart Keychain Limited Edition Degrade Monogram Vernis',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 18, 'Brand'],
#     [19, 23, 'Brand'],
#     [24, 29, 'Pattern'],
#     [30, 38, 'Accents'],
#     [39, 46, 'No Tag'],
#     [47, 54, 'No Tag'],
#     [55, 62, 'Model'],
#     [63, 71, 'Brand'],
#     [72, 78, 'Product Line']]}],
#  ['Authentic FENDI Zucca Pattern Shoulder Bag Coating Canvas Leather Brown 05MD919',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Brand'],
#     [16, 21, 'Brand'],
#     [22, 29, 'Obscure'],
#     [30, 38, 'Handle Style'],
#     [39, 42, 'Type'],
#     [43, 50, 'Fabric Type'],
#     [51, 57, 'Fabric Type'],
#     [58, 65, 'Trim Material'],
#     [66, 71, 'Color'],
#     [72, 79, 'MPN']]}],
#  ['NWT Tory Burch Black Leather Large Thea Triple Zip Satchel $ 495 - With Strap',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 8, 'Brand'],
#     [9, 14, 'Brand'],
#     [15, 20, 'Color'],
#     [21, 28, 'Trim Material'],
#     [29, 34, 'Brand'],
#     [35, 39, 'Model'],
#     [40, 46, 'Model'],
#     [47, 50, 'Pocket Type'],
#     [51, 58, 'Type'],
#     [59, 60, 'No Tag'],
#     [61, 64, 'No Tag'],
#     [65, 66, 'No Tag'],
#     [67, 71, 'Obscure'],
#     [72, 77, 'Handle/Strap Material']]}],
#  ['Shiraleah Womens Purse Geometric Design Teal Taupe & Brown Handbag Velvet Flower',
#   {'entities': [[0, 9, 'Brand'],
#     [10, 16, 'Department'],
#     [17, 22, 'Brand'],
#     [23, 32, 'Pattern'],
#     [33, 39, 'No Tag'],
#     [40, 44, 'Color'],
#     [45, 50, 'Color'],
#     [51, 52, 'Obscure'],
#     [53, 58, 'Color'],
#     [59, 66, 'Type'],
#     [67, 73, 'Fabric Type'],
#     [74, 80, 'Pattern']]}],
#  ['Louis Vuitton LV Shoulder Bag M41066 Artsy MM Black Monogram Empreinte 412790',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 16, 'Brand'],
#     [17, 25, 'Handle Style'],
#     [26, 29, 'Type'],
#     [30, 36, 'MPN'],
#     [37, 42, 'Model'],
#     [43, 45, 'Model'],
#     [46, 51, 'Brand'],
#     [52, 60, 'Brand'],
#     [61, 70, 'Accents'],
#     [71, 77, 'No Tag']]}],
#  ['Coach Field 40 Horse & Carriage Red Tote Bag NIB SOLD OUT',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 11, 'Model'],
#     [12, 14, 'Brand'],
#     [15, 20, 'Pattern'],
#     [21, 22, 'No Tag'],
#     [23, 31, 'Model'],
#     [32, 35, 'Brand'],
#     [36, 40, 'Type'],
#     [41, 44, 'Type'],
#     [45, 48, 'No Tag'],
#     [49, 53, 'No Tag'],
#     [54, 57, 'No Tag']]}],
#  ['NO STICKY ! LOUIS VUITTON Saint Cloud GM Shoulder Bag Monogram BN M51242 77MI055',
#   {'entities': [[0, 2, 'No Tag'],
#     [3, 9, 'No Tag'],
#     [10, 11, 'No Tag'],
#     [12, 17, 'Brand'],
#     [18, 25, 'Brand'],
#     [26, 31, 'Model'],
#     [32, 37, 'Style'],
#     [38, 40, 'Model'],
#     [41, 49, 'Handle Style'],
#     [50, 53, 'Type'],
#     [54, 62, 'Brand'],
#     [63, 65, 'No Tag'],
#     [66, 72, 'MPN'],
#     [73, 80, 'Brand']]}],
#  ['Kate Spade New York Robinson Street Zanni Handbag',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 14, 'Obscure'],
#     [15, 19, 'Brand'],
# ...
#     [16, 21, 'Size'],
#     [22, 30, 'No Tag'],
#     [31, 39, 'No Tag'],
#     [40, 43, 'Brand'],
#     [44, 51, 'Occasion'],
#     [52, 58, 'Occasion'],
#     [59, 62, 'Type'],
#     [63, 69, 'Brand'],
#     [70, 78, 'Brand']]}],
#  ['VALENTINA ITALIAN LEATHER CONVERTIBLE BUCKET BAG IN BLACK / TAN NWT',
#   {'entities': [[0, 9, 'Brand'],
#     [10, 17, 'Country/Region of Manufacture'],
#     [18, 25, 'Handle/Strap Material'],
#     [26, 37, 'Features'],
#     [38, 44, 'Product Line'],
#     [45, 48, 'Type'],
#     [49, 51, 'Brand'],
#     [52, 57, 'Color'],
#     [58, 59, 'No Tag'],
#     [60, 63, 'Color'],
#     [64, 67, 'No Tag']]}],
#  ['Large Genuine JIMMY CHOO Fine Leather Handbag . Luxurious Tote Bag ITALY . NICE !',
#   {'entities': [[0, 5, 'Pocket Type'],
#     [6, 13, 'No Tag'],
#     [14, 19, 'Brand'],
#     [20, 24, 'Brand'],
#     [25, 29, 'No Tag'],
#     [30, 37, 'Obscure'],
#     [38, 45, 'Type'],
#     [46, 47, 'Obscure'],
#     [48, 57, 'Theme'],
#     [58, 62, 'Type'],
#     [63, 66, 'Brand'],
#     [67, 72, 'Country/Region of Manufacture'],
#     [73, 74, 'No Tag'],
#     [75, 79, 'No Tag'],
#     [80, 81, 'No Tag']]}],
#  ['CHANEL Iridescent Lambskin Quilted Pearl Wallet on Chain WOC Black New w / Tags',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 17, 'Accents'],
#     [18, 26, 'Material'],
#     [27, 34, 'Accents'],
#     [35, 40, 'Color'],
#     [41, 47, 'Type'],
#     [48, 50, 'Brand'],
#     [51, 56, 'Handle/Strap Material'],
#     [57, 60, 'Type'],
#     [61, 66, 'Color'],
#     [67, 70, 'Brand'],
#     [71, 72, 'No Tag'],
#     [73, 74, 'No Tag'],
#     [75, 79, 'Obscure']]}],
#  ['The Sak Alameda Satchel Crossbody .',
#   {'entities': [[0, 3, 'Character'],
#     [4, 7, 'Brand'],
#     [8, 15, 'Model'],
#     [16, 23, 'Brand'],
#     [24, 33, 'Brand'],
#     [34, 35, 'No Tag']]}],
#  ['CHANEL Boy Chanel 25 Matelasse Shoulder Bag Calfskin Leather Light Grey A67086',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 10, 'Product Line'],
#     [11, 17, 'Brand'],
#     [18, 20, 'Measurement, dimension'],
#     [21, 30, 'Pattern'],
#     [31, 39, 'Handle Style'],
#     [40, 43, 'Brand'],
#     [44, 52, 'Brand'],
#     [53, 60, 'Trim Material'],
#     [61, 66, 'Color'],
#     [67, 71, 'Color'],
#     [72, 78, 'No Tag']]}],
#  ['COACH F10928 Black Signature Mini C Tote Shoulder Bag ( u200',
#   {'entities': [[0, 5, 'Brand'],
#     [6, 12, 'MPN'],
#     [13, 18, 'Brand'],
#     [19, 28, 'Pattern'],
#     [29, 33, 'Model'],
#     [34, 35, 'Brand'],
#     [36, 40, 'Brand'],
#     [41, 49, 'Handle Style'],
#     [50, 53, 'Type'],
#     [54, 55, 'No Tag'],
#     [56, 60, 'No Tag']]}],
#  ['PRADA Nylon Hand Bag Black Auth ar3378',
#   {'entities': [[0, 5, 'Brand'],
#     [6, 11, 'Lining Material'],
#     [12, 16, 'Features'],
#     [17, 20, 'Brand'],
#     [21, 26, 'Brand'],
#     [27, 31, 'No Tag'],
#     [32, 38, 'No Tag']]}],
#  ['Auth Louis Vuitton Monogram Poche Toilette 19 Cosmetics Pouch Old Model LV D1851',
#   {'entities': [[0, 4, 'No Tag'],
#     [5, 10, 'Brand'],
#     [11, 18, 'Brand'],
#     [19, 27, 'Pattern'],
#     [28, 33, 'Model'],
#     [34, 42, 'Model'],
#     [43, 45, 'Brand'],
#     [46, 55, 'Type'],
#     [56, 61, 'Type'],
#     [62, 65, 'Brand'],
#     [66, 71, 'No Tag'],
#     [72, 74, 'Brand'],
#     [75, 80, 'Obscure']]}],
#  ['Sonic the Hedgehog Face Mini Backpack Purse Bag SEGA FAUX LEATHER RARE NEW',
#   {'entities': [[0, 5, 'Character'],
#     [6, 9, 'Brand'],
#     [10, 18, 'Brand'],
#     [19, 23, 'Pattern'],
#     [24, 28, 'Model'],
#     [29, 37, 'Type'],
#     [38, 43, 'Brand'],
#     [44, 47, 'Type'],
#     [48, 52, 'Brand'],
#     [53, 57, 'Material'],
#     [58, 65, 'Handle/Strap Material'],
#     [66, 70, 'No Tag'],
#     [71, 74, 'No Tag']]}],
#  ['Longchamp Le Pliage Neo Long Handle Small Tote Handbag $ 175',
#   {'entities': [[0, 9, 'Brand'],
#     [10, 12, 'Brand'],
#     [13, 19, 'Brand'],
#     [20, 23, 'Color'],
#     [24, 28, 'No Tag'],
#     [29, 35, 'Handle Style'],
#     [36, 41, 'Brand'],
#     [42, 46, 'Type'],
#     [47, 54, 'Type'],
#     [55, 56, 'Obscure'],
#     [57, 60, 'No Tag']]}],
#  ["Chanel Black Nylon Women 's Shoulder Bag Hobo Style with silver tone CC dangle",
#   {'entities': [[0, 6, 'Brand'],
#     [7, 12, 'Color'],
#     [13, 18, 'Brand'],
#     [19, 24, 'Brand'],
#     [25, 27, 'No Tag'],
#     [28, 36, 'Handle Style'],
#     [37, 40, 'Brand'],
#     [41, 45, 'Type'],
#     [46, 51, 'No Tag'],
#     [52, 56, 'Obscure'],
#     [57, 63, 'Color'],
#     [64, 68, 'No Tag'],
#     [69, 71, 'Model'],
#     [72, 78, 'Brand']]}],
#  ['Fashion Women Leather Handbags Shoulder Bag Messenger Ladies Satchel Tote Purse',
#   {'entities': [[0, 7, 'No Tag'],
#     [8, 13, 'Department'],
#     [14, 21, 'Handle/Strap Material'],
#     [22, 30, 'Type'],
#     [31, 39, 'Handle Style'],
#     [40, 43, 'Type'],
#     [44, 53, 'Type'],
#     [54, 60, 'Brand'],
#     [61, 68, 'Type'],
#     [69, 73, 'Type'],
#     [74, 79, 'Brand']]}],
#  ['Authentic Chanel Biarritz Shoulder Black Coated Canvas GM Tote Bag and Pouch',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 16, 'Brand'],
#     [17, 25, 'Model'],
#     [26, 34, 'Handle Style'],
#     [35, 40, 'Color'],
#     [41, 47, 'Fabric Type'],
#     [48, 54, 'Brand'],
#     [55, 57, 'Model'],
#     [58, 62, 'Type'],
#     [63, 66, 'Type'],
#     [67, 70, 'Brand'],
#     [71, 76, 'Pocket Type']]}],
#  ['Vintage Gray SUEDE LEATHER Lined Coin Purse with Turquoise Beads size 4 x 4 "',
#   {'entities': [[0, 7, 'No Tag'],
#     [8, 12, 'Color'],
#     [13, 18, 'Material'],
#     [19, 26, 'Material'],
#     [27, 32, 'Features'],
#     [33, 37, 'Type'],
#     [38, 43, 'Brand'],
#     [44, 48, 'Obscure'],
#     [49, 58, 'Color'],
#     [59, 64, 'Accents'],
#     [65, 69, 'No Tag'],
#     [70, 71, 'No Tag'],
#     [72, 73, 'No Tag'],
#     [74, 75, 'Obscure']]}],
#  ['1 Dozen Duffle Bag Bags Travel Size Sports Gym Blank 17 " Wholesale Bulk Lot',
#   {'entities': [[0, 1, 'No Tag'],
#     [2, 7, 'No Tag'],
#     [8, 14, 'Type'],
#     [15, 18, 'Brand'],
#     [19, 23, 'Type'],
#     [24, 30, 'Model'],
#     [31, 35, 'No Tag'],
#     [36, 42, 'Brand'],
#     [43, 46, 'Occasion'],
#     [47, 52, 'No Tag'],
#     [53, 55, 'Brand'],
#     [68, 72, 'No Tag'],
#     [73, 76, 'No Tag']]}],
#  ['AUTHENTIC LOUIS VUITTON PURPLE EPI ZIPPY WALLET CLUTCH',
#   {'entities': [[0, 9, 'No Tag'],
#     [10, 15, 'Product Line'],
#     [16, 23, 'Brand'],
#     [24, 30, 'Color'],
#     [31, 34, 'Material'],
#     [35, 40, 'Closure'],
#     [41, 47, 'Type'],
#     [48, 54, 'Brand']]}],
#  ['Louis Vuitton Alma BB Rose Indian Monogram Vernis Leather Hand Shoulder Bag A682',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 18, 'Brand'],
#     [19, 21, 'Brand'],
#     [22, 26, 'Model'],
#     [27, 33, 'Style'],
#     [34, 42, 'Brand'],
#     [43, 49, 'Product Line'],
#     [50, 57, 'Trim Material'],
#     [58, 62, 'Type'],
#     [63, 71, 'Brand'],
#     [72, 75, 'Brand'],
#     [76, 80, 'No Tag']]}],
#  ['Vintage Far Nine Glamour Girl Faces Handbag Tote Purse Clutch',
#   {'entities': [[0, 7, 'No Tag'],
#     [8, 11, 'Pattern'],
#     [12, 16, 'Brand'],
#     [17, 24, 'Model'],
#     [25, 29, 'Department'],
#     [30, 35, 'Pattern'],
#     [36, 43, 'Type'],
#     [44, 48, 'Brand'],
#     [49, 54, 'Brand'],
#     [55, 61, 'Type']]}],
#  ['NEW Authentic Burberry Jessie Vintage Check Card Case Bag Detachable Strap',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 13, 'No Tag'],
#     [14, 22, 'Brand'],
#     [23, 29, 'Model'],
#     [30, 37, 'No Tag'],
#     [38, 43, 'Type'],
#     [44, 48, 'Features'],
#     [49, 53, 'Obscure'],
#     [54, 57, 'Type'],
#     [58, 68, 'Handle Style'],
#     [69, 74, 'Handle/Strap Material']]}],
#  ['Fashion Hill Tribe Purse Thai Hmong Embroidered Crossbody Bag Gypsy Boho Hippie',
#   {'entities': [[0, 7, 'No Tag'],
#     [8, 12, 'Brand'],
#     [13, 18, 'Brand'],
#     [19, 24, 'Brand'],
#     [25, 29, 'Country/Region of Manufacture'],
#     [30, 35, 'Brand'],
#     [36, 47, 'Brand'],
#     [48, 57, 'Type'],
#     [58, 61, 'Type'],
#     [62, 67, 'Style'],
#     [68, 72, 'Style'],
#     [73, 79, 'Style']]}],
#  ['❤ BRAHMIN MINI SONNY GOLD BROWN FRESCO SADDLE BAG CROSSBODY TASSEL LEATHER NWT ❤',
#   {'entities': [[0, 1, 'No Tag'],
#     [2, 9, 'Brand'],
#     [10, 14, 'Brand'],
#     [15, 20, 'Model'],
#     [21, 25, 'Color'],
#     [26, 31, 'Color'],
#     [32, 38, 'Accents'],
#     [39, 45, 'Type'],
#     [46, 49, 'Type'],
#     [50, 59, 'Type'],
#     [60, 66, 'Accents'],
#     [67, 74, 'Trim Material'],
#     [75, 78, 'No Tag'],
#     [79, 80, 'No Tag']]}],
#  ['Louis Vuitton LV x NBA Basketball Keepall Bag Monogram Antarctica Canvas 55',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 16, 'Brand'],
#     [17, 18, 'Brand'],
#     [19, 22, 'Brand'],
#     [23, 33, 'Style'],
#     [34, 41, 'Product Line'],
#     [42, 45, 'Type'],
#     [46, 54, 'Pattern'],
#     [55, 65, 'Color'],
#     [66, 72, 'Brand'],
#     [73, 75, 'No Tag']]}],
#  ['LOUIS VUITTON Pochette Accessoires Hand Bag Monogram Leather BN M51980 82SC765',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 22, 'Model'],
#     [23, 34, 'Brand'],
#     [35, 39, 'No Tag'],
#     [40, 43, 'Type'],
#     [44, 52, 'Brand'],
#     [53, 60, 'Handle/Strap Material'],
#     [61, 63, 'No Tag'],
#     [64, 70, 'MPN'],
#     [71, 78, 'No Tag']]}],
#  ['COACH 14562 Signature Poppy Op Art Purse / Crossbody Bag',
#   {'entities': [[0, 5, 'Brand'],
#     [6, 11, 'No Tag'],
#     [12, 21, 'Accents'],
#     [22, 27, 'Pattern'],
#     [28, 30, 'Model'],
#     [31, 34, 'Brand'],
#     [35, 40, 'Brand'],
#     [41, 42, 'Handle/Strap Material'],
#     [43, 52, 'Type'],
#     [53, 56, 'Type']]}],
#  ["New Genuine Leather Women 's Handbag Shoulder Tote Purse Messenger Satchel S Bag",
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 11, 'No Tag'],
#     [12, 19, 'Handle/Strap Material'],
#     [20, 25, 'Brand'],
#     [26, 28, 'No Tag'],
#     [29, 36, 'Type'],
#     [37, 45, 'Brand'],
#     [46, 50, 'Type'],
#     [51, 56, 'Type'],
#     [57, 66, 'Type'],
#     [67, 74, 'Brand'],
#     [75, 76, 'No Tag'],
#     [77, 80, 'Type']]}],
#  ['JUDITH LEIBER SWAROVSKI CRYSTAL STAINED GLASS PEARL ROSE PURSE BAG CLUTCH SILVER',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 13, 'Brand'],
#     [14, 23, 'Accents'],
#     [24, 31, 'Brand'],
#     [32, 39, 'Brand'],
#     [40, 45, 'Brand'],
#     [46, 51, 'Brand'],
#     [52, 56, 'Color'],
#     [57, 62, 'Brand'],
#     [63, 66, 'Type'],
#     [67, 73, 'Brand'],
#     [74, 80, 'Color']]}],
#  ['Vintage Louis Vuitton Opera Delphes Black Leather Shoulder Bag',
#   {'entities': [[0, 7, 'No Tag'],
#     [8, 13, 'Brand'],
#     [14, 21, 'Brand'],
#     [22, 27, 'Model'],
#     [28, 35, 'Brand'],
#     [36, 41, 'Color'],
#     [42, 49, 'Handle/Strap Material'],
#     [50, 58, 'Handle Style'],
#     [59, 62, 'Type']]}],
#  ['Dooney & Bourke Vintage Belt Bag Crossbody Black Brown AWL R700 Pebbled Leather',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 8, 'Brand'],
#     [9, 15, 'Brand'],
#     [16, 23, 'No Tag'],
#     [24, 28, 'Type'],
#     [29, 32, 'Type'],
#     [33, 42, 'Brand'],
#     [43, 48, 'Color'],
#     [49, 54, 'Color'],
#     [55, 58, 'Model'],
#     [59, 63, 'No Tag'],
#     [64, 71, 'Pattern'],
#     [72, 79, 'Trim Material']]}],
#  ['Gothic Steampunk Waist Bag Leather Motorcycle Leg Drop Bag Hip Holster Purse',
#   {'entities': [[0, 6, 'Theme'],
#     [7, 16, 'Brand'],
#     [17, 22, 'Style'],
#     [23, 26, 'Brand'],
#     [27, 34, 'Trim Material'],
#     [35, 45, 'Theme'],
#     [46, 49, 'No Tag'],
#     [50, 54, 'Brand'],
#     [55, 58, 'Type'],
#     [59, 62, 'Type'],
#     [63, 70, 'Style'],
#     [71, 76, 'Brand']]}],
#  ['Chanel Herringbone CC SHW Shoulder Bag Calfskin Leather Silver',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 18, 'Pattern'],
#     [19, 21, 'Accents'],
#     [22, 25, 'No Tag'],
#     [26, 34, 'Handle Style'],
#     [35, 38, 'Type'],
#     [39, 47, 'Material'],
#     [48, 55, 'Handle/Strap Material'],
#     [56, 62, 'Color']]}],
#  ['Chanel Quilted CC Chain Shoulder Bag Patent Leather Green',
#   {'entities': [[0, 6, 'Brand'],
#     [7, 14, 'Accents'],
#     [15, 17, 'Accents'],
#     [18, 23, 'Brand'],
#     [24, 32, 'Handle Style'],
#     [33, 36, 'Type'],
#     [37, 43, 'Material'],
#     [44, 51, 'Handle/Strap Material'],
#     [52, 57, 'Brand']]}],
#  ['LOUIS VUITTON Monogram Cabas Piano Tote Bag Brown M51148 Purse 90125376',
#   {'entities': [[0, 5, 'Product Line'],
#     [6, 13, 'Brand'],
#     [14, 22, 'Pattern'],
#     [23, 28, 'Brand'],
#     [29, 34, 'Brand'],
#     [35, 39, 'Brand'],
#     [40, 43, 'Brand'],
#     [44, 49, 'Color'],
#     [50, 56, 'MPN'],
#     [57, 62, 'Type'],
#     [63, 71, 'No Tag']]}],
#  ['All Purpose Travel Laundry Shopping Zipper Utility Shoulder Tote Bag Pink Ballet',
#   {'entities': [[0, 3, 'Occasion'],
#     [4, 11, 'Obscure'],
#     [12, 18, 'Brand'],
#     [19, 26, 'Obscure'],
#     [27, 35, 'Product Line'],
#     [36, 42, 'Closure'],
#     [43, 50, 'No Tag'],
#     [51, 59, 'Handle Style'],
#     [60, 64, 'Type'],
#     [65, 68, 'Type'],
#     [69, 73, 'Brand'],
#     [74, 80, 'Color']]}],
#  ['$ 249 NWT Patricia Nash Crossbody Simona Top Handle Satchel Wavy Stripe Leather',
#   {'entities': [[0, 1, 'No Tag'],
#     [2, 5, 'No Tag'],
#     [6, 9, 'No Tag'],
#     [10, 18, 'Brand'],
#     [19, 23, 'Brand'],
#     [24, 33, 'Type'],
#     [34, 40, 'Model'],
#     [41, 44, 'Style'],
#     [45, 51, 'No Tag'],
#     [52, 59, 'Type'],
#     [60, 64, 'Pattern'],
#     [65, 71, 'Pattern'],
#     [72, 79, 'Trim Material']]}],
#  ['100 % Authentic Taupe Fendi Be Baguette MSRP $ 2950 !',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 5, 'No Tag'],
#     [6, 15, 'No Tag'],
#     [16, 21, 'Color'],
#     [22, 27, 'Brand'],
#     [28, 30, 'No Tag'],
#     [31, 39, 'Type'],
#     [40, 44, 'Obscure'],
#     [45, 46, 'Obscure'],
#     [47, 51, 'No Tag'],
#     [52, 53, 'No Tag']]}],
#  ['Brand New Spartina 449 Drifter Tote 28 Shelter Cove 295436 NWT Bag Purse',
#   {'entities': [[0, 5, 'No Tag'],
#     [6, 9, 'Country/Region of Manufacture'],
#     [10, 18, 'Brand'],
#     [19, 22, 'Model'],
#     [23, 30, 'Brand'],
#     [31, 35, 'Type'],
#     [36, 38, 'Brand'],
#     [39, 46, 'Brand'],
#     [47, 51, 'Brand'],
#     [52, 58, 'No Tag'],
#     [59, 62, 'No Tag'],
#     [63, 66, 'Brand'],
#     [67, 72, 'Type']]}],
#  ["Just Cavalli Leather Brown Women 's Shoulder Tote Bag",
#   {'entities': [[0, 4, 'Brand'],
#     [5, 12, 'Brand'],
#     [13, 20, 'Handle/Strap Material'],
#     [21, 26, 'Color'],
#     [27, 32, 'Department'],
#     [33, 35, 'Obscure'],
#     [36, 44, 'Brand'],
#     [45, 49, 'Type'],
#     [50, 53, 'Type']]}],
#  ['MINICAT RFID Blocking Small Crossbody Bags for Women Travel Small Purses and Han',
#   {'entities': [[0, 7, 'Brand'],
#     [8, 12, 'Features'],
#     [13, 21, 'Brand'],
#     [22, 27, 'Brand'],
#     [28, 37, 'Type'],
#     [38, 42, 'Type'],
#     [43, 46, 'Brand'],
#     [47, 52, 'Brand'],
#     [53, 59, 'Occasion'],
#     [60, 65, 'Brand'],
#     [66, 72, 'Type'],
#     [73, 76, 'No Tag'],
#     [77, 80, 'No Tag']]}],
#  ['Brahmin Duxbury Elmwood Padua Mossy Green Brown Leather Bag + CB Wallet NWT ** HTF',
#   {'entities': [[0, 7, 'Brand'],
#     [8, 15, 'Product Line'],
#     [16, 23, 'Model'],
#     [24, 29, 'Brand'],
#     [30, 35, 'Color'],
#     [36, 41, 'Color'],
#     [42, 47, 'Color'],
#     [48, 55, 'Handle/Strap Material'],
#     [56, 59, 'Type'],
#     [60, 61, 'Obscure'],
#     [62, 64, 'No Tag'],
#     [65, 71, 'Type'],
#     [72, 75, 'No Tag'],
#     [76, 78, 'No Tag'],
#     [79, 82, 'No Tag']]}],
#  ['Women Backpack Satchel Book Bags Travel Causal Rucksack School bag Leather Small',
#   {'entities': [[0, 5, 'Department'],
#     [6, 14, 'Brand'],
#     [15, 22, 'Brand'],
#     [23, 27, 'Theme'],
#     [28, 32, 'Type'],
#     [33, 39, 'Model'],
#     [40, 46, 'Brand'],
#     [47, 55, 'Type'],
#     [56, 62, 'Occasion'],
#     [63, 66, 'Type'],
#     [67, 74, 'Handle/Strap Material'],
#     [75, 80, 'Brand']]}],
#  ['NWT Coach F52657 East West Popup Crossbody Handbag Brown Signature $ 195',
#   {'entities': [[0, 3, 'No Tag'],
#     [4, 9, 'Brand'],
#     [10, 16, 'MPN'],
#     [17, 21, 'Product Line'],
#     [22, 26, 'Model'],
#     [27, 32, 'Model'],
#     [33, 42, 'Brand'],
#     [43, 50, 'Type'],
#     [51, 56, 'Color'],
#     [57, 66, 'Accents'],
#     [67, 68, 'No Tag'],
#     [69, 72, 'No Tag']]}],
#  ['Prada James Jean Shoulder Bag Etiquette Line Rabbit Bunny Leather Pink w / Box',
#   {'entities': [[0, 5, 'Brand'],
#     [6, 11, 'Model'],
#     [12, 16, 'Brand'],
#     [17, 25, 'Handle Style'],
#     [26, 29, 'Type'],
#     [30, 39, 'Product Line'],
#     [40, 44, 'Brand'],
#     [45, 51, 'Theme'],
#     [52, 57, 'Pattern'],
#     [58, 65, 'Handle/Strap Material'],
#     [66, 70, 'Brand'],
#     [71, 72, 'No Tag'],
#     [73, 74, 'No Tag'],
#     [75, 78, 'Obscure']]}],
#  ...]

# %%
# Use saved TRAIN_DATA dataset to train a brand new spacy model
def train_spacy(data, iterations):
  TRAIN_DATA = data
  nlp = spacy.blank('en')
  if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe('ner', last = True)
  for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
      ner.add_label(ent[2])   
  other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
  with nlp.disable_pipes(*other_pipes):
    optimizer = nlp.begin_training()
    for itn in range(iterations):
      print('Starting iteration ' + str(itn))
      random.shuffle(TRAIN_DATA)
      losses = {}
      for text, annotations in TRAIN_DATA:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, annotations)
        # print(text)
        nlp.update([example], drop = 0.2, sgd = optimizer, losses = losses)
      print(losses)
  return(nlp)
TRAIN_DATA = load_data('./ebay_training_data.json')
nlp = train_spacy(TRAIN_DATA, 30)
# nlp.to_disk('./ebay/ebay_ner_model')
# Out:
# Starting iteration 0
# {'ner': 24425.538804872896}
# Starting iteration 1
# {'ner': 20217.51166151509}
# Starting iteration 2
# {'ner': 18530.201679562815}
# Starting iteration 3
# {'ner': 17352.000352510673}
# Starting iteration 4
# {'ner': 16566.957261032403}
# Starting iteration 5
# {'ner': 15884.705238123359}
# Starting iteration 6
# {'ner': 15348.434159244578}
# Starting iteration 7
# {'ner': 14699.122328524763}
# Starting iteration 8
# {'ner': 14301.653136940295}
# Starting iteration 9
# {'ner': 13682.097132907971}
# Starting iteration 10
# {'ner': 13483.701193121738}
# Starting iteration 11
# {'ner': 13146.150753692182}
# Starting iteration 12
# {'ner': 12698.658584634957}
# Starting iteration 13
# {'ner': 12523.001094375588}
# Starting iteration 14
# {'ner': 12123.478287795844}
# Starting iteration 15
# {'ner': 11821.19146760415}
# Starting iteration 16
# {'ner': 11615.373793066909}
# Starting iteration 17
# {'ner': 11328.212785259013}
# Starting iteration 18
# {'ner': 11178.251868464113}
# Starting iteration 19
# {'ner': 10783.084737452542}
# Starting iteration 20
# {'ner': 10708.823873070676}
# Starting iteration 21
# {'ner': 10613.619291483054}
# Starting iteration 22
# {'ner': 10260.429208885134}
# Starting iteration 23
# {'ner': 10197.578981376017}
# Starting iteration 24
# {'ner': 9906.67541939402}
# Starting iteration 25
# {'ner': 9829.547841047766}
# Starting iteration 26
# {'ner': 9735.100511964893}
# Starting iteration 27
# {'ner': 9620.087589484008}
# Starting iteration 28
# {'ner': 9457.260259619678}
# Starting iteration 29
# {'ner': 9446.568668817195}

# %%
# Create a function to get ebay nlp model performance evaluation metrix
def my_evaluate(model, examples):
  # Create Scorer class
  scorer = Scorer() 
  # Create empty list
  example = []
  # Loop through examples
  for input_, annotations in examples: 
    # Predict
    pred = model(input_)
    print(pred, annotations)
    # Create Example instance
    temp = Example.from_dict(pred, annotations)
    # append to example list
    example.append(temp)
  # Get Scores
  scores = scorer.score(example)
  return scores

# %%
# Get score of model from my_evaluate
score = my_evaluate(nlp,TRAIN_DATA)
print(score)
# Out:
# 4 Pieces Women Leather Handbag Casual Shoulder Bag Tote Messenger Bag Ladies New {'entities': [[0, 1, 'No Tag'], [2, 8, 'No Tag'], [9, 14, 'Department'], [15, 22, 'Material'], [23, 30, 'Type'], [31, 37, 'Occasion'], [38, 46, 'Brand'], [47, 50, 'Type'], [51, 55, 'Type'], [56, 65, 'Type'], [66, 69, 'Brand'], [70, 76, 'Brand'], [77, 80, 'No Tag']]}
# VERIFIED Authentic CHANEL Quilted Studded Paris-Dallas Medium Boy Flap Bag RARE {'entities': [[0, 8, 'No Tag'], [9, 18, 'No Tag'], [19, 25, 'Brand'], [26, 33, 'Accents'], [34, 41, 'Accents'], [42, 54, 'Model'], [55, 61, 'Size'], [62, 65, 'Product Line'], [66, 70, 'Brand'], [71, 74, 'Brand'], [75, 79, 'No Tag']]}
# Louis Vuitton Monogram Tivoli {'entities': [[0, 5, 'Product Line'], [6, 13, 'Brand'], [14, 22, 'Pattern'], [23, 29, 'Model']]}
# VTG Brahmin USA Mass Crossbody Purse Navy Blue Leather Smooth Saddle CROC Bag {'entities': [[0, 3, 'No Tag'], [4, 11, 'Brand'], [12, 15, 'No Tag'], [16, 20, 'No Tag'], [21, 30, 'Type'], [31, 36, 'Type'], [37, 41, 'Color'], [42, 46, 'Color'], [47, 54, 'Trim Material'], [55, 61, 'Pattern'], [62, 68, 'Type'], [69, 73, 'Pattern'], [74, 77, 'Type']]}
# NWT Coach Kleo Shoulder Bag 23 In Signature Canvas large size {'entities': [[0, 3, 'No Tag'], [4, 9, 'Brand'], [10, 14, 'Model'], [15, 23, 'Handle Style'], [24, 27, 'Type'], [28, 30, 'Model'], [31, 33, 'Brand'], [34, 43, 'Brand'], [44, 50, 'Obscure'], [51, 56, 'Size'], [57, 61, 'No Tag']]}
# Chanel Shoulder Bag Light Brown Leather 1442085 {'entities': [[0, 6, 'Brand'], [7, 15, 'Handle Style'], [16, 19, 'Type'], [20, 25, 'Color'], [26, 31, 'Color'], [32, 39, 'Brand'], [40, 47, 'No Tag']]}
# CHANEL CC Mark Chain Shoulder Large Tote Bag Caviar Leather Black E + + {'entities': [[0, 6, 'Brand'], [7, 9, 'Accents'], [10, 14, 'Accents'], [15, 20, 'Brand'], [21, 29, 'Handle Style'], [30, 35, 'Brand'], [36, 40, 'Brand'], [41, 44, 'Type'], [45, 51, 'Product Line'], [52, 59, 'Handle/Strap Material'], [60, 65, 'Brand'], [66, 67, 'No Tag'], [68, 69, 'No Tag'], [70, 71, 'Obscure']]}
# NWT Handbag Calvin Klein H3ADW1AM Handbag Satchel Modena Leather WHITE {'entities': [[0, 3, 'No Tag'], [4, 11, 'Type'], [12, 18, 'Brand'], [19, 24, 'Brand'], [25, 33, 'No Tag'], [34, 41, 'Type'], [42, 49, 'Brand'], [50, 56, 'Model'], [57, 64, 'Handle/Strap Material'], [65, 70, 'Color']]}
# Handle Small bags 13cm * 18cm * 18cm {'entities': [[0, 6, 'No Tag'], [7, 12, 'Brand'], [13, 17, 'Type'], [18, 22, 'Measurement, dimension'], [23, 24, 'Obscure'], [25, 29, 'Measurement, dimension'], [30, 31, 'No Tag'], [32, 36, 'Measurement, dimension']]}
# Louis Vuitton Epi Biarritz Shoulder Bag Vanilla {'entities': [[0, 5, 'Product Line'], [6, 13, 'Brand'], [14,
': 0.8779296875}, 'Country/Region of Manufacture': {'p': 0.9241706161137441, 'r': 0.9420289855072463, 'f': 0.9330143540669857}, 'Season': {'p': 0.9285714285714286, 'r': 0.8666666666666667, 'f': 0.896551724137931}, 'Fabric Type': {'p': 0.9646464646464646, 'r': 0.8162393162393162, 'f': 0.8842592592592592}, 'Closure': {'p': 0.822429906542056, 'r': 0.967032967032967, 'f': 0.888888888888889}, 'Size': {'p': 0.9628378378378378, 'r': 0.9437086092715232, 'f': 0.9531772575250835}, 'Trim Material': {'p': 0.9365671641791045, 'r': 0.7130681818181818, 'f': 0.8096774193548387}, 'Features': {'p': 0.9238845144356955, 'r': 0.8167053364269141, 'f': 0.8669950738916256}, 'Style': {'p': 0.9362880886426593, 'r': 0.8711340206185567, 'f': 0.9025367156208279}, 'Character Family': {'p': 0.9655172413793104, 'r': 0.9655172413793104, 'f': 0.9655172413793104}, 'Measurement, dimension': {'p': 0.9072164948453608, 'r': 0.9166666666666666, 'f': 0.9119170984455958}, 'Hardware Material': {'p': 0.8416666666666667, 'r': 0.9439252336448598, 'f': 0.8898678414096917}, 'Lining Material': {'p': 0.9090909090909091, 'r': 0.4166666666666667, 'f': 0.5714285714285715}, 'Strap Drop': {'p': 1.0, 'r': 0.4, 'f': 0.5714285714285715}, 'Handle Drop': {'p': 1.0, 'r': 0.5, 'f': 0.6666666666666666}}, 'cats_score': 0.0, 'cats_score_desc': 'macro F', 'cats_micro_p': 0.0, 'cats_micro_r': 0.0, 'cats_micro_f': 0.0, 'cats_macro_p': 0.0, 'cats_macro_r': 0.0, 'cats_macro_f': 0.0, 'cats_macro_auc': 0.0, 'cats_f_per_type': {}, 'cats_auc_per_type': {}}

# %% [markdown]
# ## Create train, test set to train NER model

# %%
output_path = './ebay'

# %%
import srsly
import typer
import warnings
from tqdm import tqdm
from pathlib import Path
from spacy.tokens import DocBin

def convert(lang: str, TRAIN_DATA, output_path: Path):
    nlp = spacy.blank(lang)
    db = DocBin()
    for text, annot in TRAIN_DATA:
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label)
            if span is None:
                msg = f"Skipping entity [{start}, {end}, {label}] in the following text because the character span '{doc.text[start:end]}' does not align with token boundaries:\n\n{repr(text)}\n"
                warnings.warn(msg)
            else:
                ents.append(span)
        doc.ents = ents
        db.add(doc)
    db.to_disk(output_path)

# %%
sentance_list = lt_sm['Title'].tolist()

# %%
train = sentance_list[:4993]
valid = sentance_list[4994:]

# %%
nlp = spacy.blank('en')
def create_training(TRAIN_DATA):
  db = DocBin()
  for text, annot in tqdm(TRAIN_DATA):
    doc = nlp.make_doc(text)
    ents = []
    for label in annot['entities']:
      span = doc.char_span(label = label, alignment_mode = 'contract')
      if span is None:
        print('Skipping entity')
      else:
        ents.append(span)
    doc.ents = ents
    db.add(doc)
  return(db)

# %%
train = create_training(train)
train.to_disk('./ebay/train.spacy')

# %%
valid = create_training(valid)
valid.to_disk('./ebay/valid.spacy')
